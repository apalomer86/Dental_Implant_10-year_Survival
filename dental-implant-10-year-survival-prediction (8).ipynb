# %% [markdown]
# # **Dental Implant 10-Year Survival Prediction**

# %% [markdown]
# ---
# ---
# # **1.  Brief description of the problem and data**
#
# ---
# ### Overview
#
# In this project, we use deep learning models to predict the 10-year survival of a dental implant for each patient in our dataset. How will our predictions compare with the
# ${\color{RoyalBlue}{90.94\%}}$
# survival rate seen in the real world?
#
# Models are evaluated primarily on the ROC-AUC score (ROC Area Under the Curve) between the predicted probability and observed target. F1-score is used a secondary metric.

# %%
# =============================
# Import libraries
# =============================

# Silence Warnings
import warnings
warnings.filterwarnings("ignore")

# General libraries
import os
import numpy as np
import pandas as pd
from IPython.display import display, HTML

# Visualizations
import matplotlib.pyplot as plt

# sklearn
from sklearn.model_selection import train_test_split, StratifiedKFold
from sklearn.metrics import f1_score, roc_auc_score, confusion_matrix
from sklearn.preprocessing import StandardScaler
from sklearn.utils import class_weight

# TensorFlow
import tensorflow as tf
from tensorflow.keras.metrics import Precision, Recall
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import (Input, Dense, Dropout, BatchNormalization,
    Conv1D, MaxPooling1D, GlobalMaxPooling1D, Flatten, concatenate)
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow.keras.regularizers import l2

# Input data files are available in the read-only "../input/" directory
import os
for dirname, _, filenames in os.walk("/kaggle/input"):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# 2025-12-09 01:56:23.415005: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1765245383.443862  216423 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1765245383.452240  216423 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# /kaggle/input/dental-implant-10-year-survival-prediction/sample_submission.csv
# /kaggle/input/dental-implant-10-year-survival-prediction/train.csv
# /kaggle/input/dental-implant-10-year-survival-prediction/test.csv

# %%
# Set random_state for reproducibility
random_state = 86

# %% [markdown]
# <br>
#
# ---
# ---
# # **2.  Exploratory Data Analysis (EDA)**
#
# ---
# ## Import and Load Data
#
# Our raw data comes in two tabulated tabulated .csv files—one for the train data and one for the test data. Their sizes are:
#
# * **Train Raw:** &ensp;
#   ${\color{ForestGreen}{7000}}$ rows × ${\color{MediumSeaGreen}{20}}$ columns
# * **Test Raw:** &emsp;
#   ${\color{ForestGreen}{3000}}$ rows × ${\color{MediumSeaGreen}{19}}$ columns
#
# The train data has
# ${\color{MediumSeaGreen}{20}}$
# columns listed in the table below. The column `implant_survival_10y` is not available in the test data because our goal is to classify the patients in that dataset with the appropriate prediction regarding the 10-year survival of their dental implant.
#
# | **Column**              | **Meaning**                                                           |
# |:------------------------|:----------------------------------------------------------------------|
# | `patient_id`            | Unique identifier for each patient.                                   |
# | `age`                   | Age of the patient at the time of implant placement.                  |
# | `gender`                | Biological sex of the patient.                                        |
# | `smoking_status`        | Patient's smoking habits (Non-smoker, Former, Light, Heavy).          |
# | `diabetes`              | Presence of diabetes mellitus (0 = No, 1 = Yes).                      |
# | `vitamin_d_deficiency`  | Vitamin D deficiency status (0 = No, 1 = Yes).                        |
# | `history_periodontitis` | Previous diagnosis of periodontal disease (0 = No, 1 = Yes).          |
# | `bruxism`               | Parafunctional grinding/clenching habit (0 = No, 1 = Yes).            |
# | `oral_hygiene`          | Patient's oral hygiene status (Good, Fair, Poor).                     |
# | `bone_quality`          | Bone density classification (Type_1, Type_2, Type_3, Type_4).         |
# | `jaw_location`          | Location of implant placement (Maxilla, Mandible).                    |
# | `implant_length_mm`     | Length of the implant in millimeters.                                 |
# | `implant_diameter_mm`   | Diameter of the implant in millimeters.                               |
# | `implant_surface`       | Surface treatment type of the implant.                                |
# | `placement_timing`      | Timing of implant placement after tooth extraction (Immediate, Early, Delayed). |
# | `insertion_torque_ncm`  | Rotational force during placement in Newton-centimeters.              |
# | `bone_augmentation`     | Whether a bone graft or sinus lift was performed (0 = No, 1 = Yes).   |
# | `loading_protocol`      | Timing of prosthetic loading (Immediate, Early, Delayed).             |
# | `restoration_type`      | Type of prosthetic restoration (Single_Crown, Bridge, Overdenture).   |
# | `implant_survival_10y`  | **(TARGET)** Whether the implant survived for 10 years (0 = Failed, 1 = Survived). |

# %%
# =============================
# Load files
# =============================
train_raw = pd.read_csv(
    "/kaggle/input/dental-implant-10-year-survival-prediction/train.csv")
test_raw = pd.read_csv(
    "/kaggle/input/dental-implant-10-year-survival-prediction/test.csv")
sample_submission = pd.read_csv(
    "/kaggle/input/dental-implant-10-year-survival-prediction/sample_submission.csv")

# %%
# =============================
# Initial look at data .info()
# =============================

# Check train data
display(HTML(f"<strong>Train Raw Data</strong>"))
train_raw.info()

# Check test data
display(HTML(f"<br><strong>Test Raw Data</strong>"))
test_raw.info()
# Out:
# <strong>Train Raw Data</strong>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 20 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   patient_id             7000 non-null   int64
#  1   age                    7000 non-null   int64
#  2   gender                 7000 non-null   object
#  3   smoking_status         7000 non-null   object
#  4   diabetes               7000 non-null   int64
#  5   vitamin_d_deficiency   7000 non-null   int64
#  6   history_periodontitis  7000 non-null   int64
#  7   bruxism                7000 non-null   int64
#  8   oral_hygiene           7000 non-null   object
#  9   bone_quality           7000 non-null   object
#  10  jaw_location           7000 non-null   object
#  11  implant_length_mm      7000 non-null   float64
#  12  implant_diameter_mm    7000 non-null   float64
#  13  implant_surface        7000 non-null   object
#  14  placement_timing       7000 non-null   object
#  15  insertion_torque_ncm   7000 non-null   int64
#  16  bone_augmentation      7000 non-null   int64
#  17  loading_protocol       7000 non-null   object
#  18  restoration_type       7000 non-null   object
#  19  implant_survival_10y   7000 non-null   int64
# dtypes: float64(2), int64(9), object(9)
# memory usage: 1.1+ MB
# <br><strong>Test Raw Data</strong>
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 19 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   patient_id             3000 non-null   int64
#  1   age                    3000 non-null   int64
#  2   gender                 3000 non-null   object
#  3   smoking_status         3000 non-null   object
#  4   diabetes               3000 non-null   int64
#  5   vitamin_d_deficiency   3000 non-null   int64
#  6   history_periodontitis  3000 non-null   int64
#  7   bruxism                3000 non-null   int64
#  8   oral_hygiene           3000 non-null   object
#  9   bone_quality           3000 non-null   object
#  10  jaw_location           3000 non-null   object
#  11  implant_length_mm      3000 non-null   float64
#  12  implant_diameter_mm    3000 non-null   float64
#  13  implant_surface        3000 non-null   object
#  14  placement_timing       3000 non-null   object
#  15  insertion_torque_ncm   3000 non-null   int64
#  16  bone_augmentation      3000 non-null   int64
#  17  loading_protocol       3000 non-null   object
#  18  restoration_type       3000 non-null   object
# dtypes: float64(2), int64(8), object(9)
# memory usage: 445.4+ KB

# %%
# =============================
# View data .head()
# =============================

# Check train data
display(HTML(f"<strong>Train Raw Data</strong>"))
print(f"Size:    {train_raw.shape[0]} rows × {train_raw.shape[1]} columns")
display(train_raw.head())

# Check test data
display(HTML(f"<br><strong>Test Raw Data</strong>"))
print(f"Size:    {test_raw.shape[0]} rows × {test_raw.shape[1]} columns")
display(test_raw.head())
# Out:
# <strong>Train Raw Data</strong>
# Size:    7000 rows × 20 columns
#    patient_id  age  gender smoking_status  diabetes  vitamin_d_deficiency  \
# 0        6253   83    Male     Non-smoker         0                     0
# 1        4685   39  Female         Former         0                     0
# 2        1732   47    Male          Light         0                     0
# 3        4743   52    Male     Non-smoker         0                     0
# 4        4522   64    Male          Light         0                     0
#
#    history_periodontitis  bruxism oral_hygiene bone_quality jaw_location  \
# 0                      1        0         Fair       Type_2      Maxilla
# 1                      0        0         Fair       Type_2      Maxilla
# 2                      1        1         Fair       Type_2      Maxilla
# 3                      0        1         Poor       Type_2     Mandible
# 4                      1        1         Fair       Type_1      Maxilla
#
#    implant_length_mm  implant_diameter_mm implant_surface placement_timing  \
# 0                8.3                  4.1             SLA          Delayed
# 1               11.4                  4.5             SLA          Delayed
# 2               13.7                  4.1             SLA          Delayed
# 3               13.0                  4.9        SLActive          Delayed
# 4               11.9                  3.5             SLA            Early
#
#    insertion_torque_ncm  bone_augmentation loading_protocol restoration_type  \
# 0                    29                  0            Early     Single_Crown
# 1                    16                  0        Immediate           Bridge
# 2                    39                  1        Immediate           Bridge
# 3                    41                  0          Delayed     Single_Crown
# 4                    63                  1          Delayed     Single_Crown
#
#    implant_survival_10y
# 0                     1
# 1                     1
# 2                     1
# 3                     1
# 4                     1
# <br><strong>Test Raw Data</strong>
# Size:    3000 rows × 19 columns
#    patient_id  age  gender smoking_status  diabetes  vitamin_d_deficiency  \
# 0        5526   44    Male     Non-smoker         0                     0
# 1         772   45    Male     Non-smoker         0                     0
# 2        7840   47    Male     Non-smoker         0                     0
# 3        2396   34    Male     Non-smoker         0                     1
# 4        1479   41  Female         Former         0                     0
#
#    history_periodontitis  bruxism oral_hygiene bone_quality jaw_location  \
# 0                      0        0         Good       Type_2     Mandible
# 1                      0        0         Good       Type_1     Mandible
# 2                      1        1         Fair       Type_1     Mandible
# 3                      0        0         Good       Type_2      Maxilla
# 4                      0        0         Fair       Type_3      Maxilla
#
#    implant_length_mm  implant_diameter_mm implant_surface placement_timing  \
# 0               10.8                  3.2         TiUnite          Delayed
# 1               10.3                  4.6         TiUnite          Delayed
# 2               12.9                  4.3             SLA            Early
# 3               15.2                  4.9        SLActive          Delayed
# 4               12.4                  4.1             SLA          Delayed
#
#    insertion_torque_ncm  bone_augmentation loading_protocol restoration_type
# 0                    37                  1          Delayed     Single_Crown
# 1                    43                  1            Early     Single_Crown
# 2                    51                  0          Delayed     Single_Crown
# 3                    43                  0        Immediate     Single_Crown
# 4                    39                  0          Delayed     Single_Crown

# %%
# ============================
# Check for dupes and nulls.
# ============================

# Check train_raw
display(HTML(f"<strong>Train Raw Data</strong>"))
print(f"Size:    {train_raw.shape[0]} rows × {train_raw.shape[1]} columns")
train_duplicates = train_raw.duplicated().sum()
print(f"Number of duplicates:    {train_duplicates}")
train_nulls = train_raw.isnull().sum().sum()
print(f"Number of nulls:         {train_nulls}")

# Check test_raw
display(HTML(f"<br><strong>Test Raw Data</strong>"))
print(f"Size:    {test_raw.shape[0]} rows × {test_raw.shape[1]} columns")
test_duplicates = test_raw.duplicated().sum()
print(f"Number of duplicates:    {test_duplicates}")
test_nulls = test_raw.isnull().sum().sum()
print(f"Number of nulls:         {test_nulls}")
# Out:
# <strong>Train Raw Data</strong>
# Size:    7000 rows × 20 columns
# Number of duplicates:    0
# Number of nulls:         0
# <br><strong>Test Raw Data</strong>
# Size:    3000 rows × 19 columns
# Number of duplicates:    0
# Number of nulls:         0

# %% [markdown]
# ---
# ## Data Preprocessing
#
# I looked over my variables again and manually assigned them to groups. Additionally, I manually assigned variables to encodings based on their `dtype`. The table below shows this hierarchical organization. From here, we sliced our train and test data into separate slices based on their group + encoding.
#
# > I did this because I initially planned on building a 1D convolution model with each of these group + encoding categories feeding into a separate covolutional layer. When I ran my MLP model, I quickly learned that too many layers was asking for overfitting. I abandoned this idea for modeling, but this made my visualizations cleaner.
#
# | **group**      | **encodings** | **meaning**                    | **variables** |
# |:---------------|:--------------|:-------------------------------|:--------------|
# | **id**         | id            | primary key patient identifier | `patient_id` |
# | **pt**         | binary        | patient-related factors        | `diabetes`, `vitamin_d_deficiency` |
# |                | categorical   |                                | `gender`, `smoking_status` |
# |                | numeric       |                                | `age` |
# | **clinical**   | binary        | clinical and intraoral factors | `history_periodontitis`, `bruxism` |
# |                | categorical   |                                | `oral_hygiene`, `bone_quality`, `jaw_location` |
# | **implant**    | categorical   | implant-related factors        | `implant_surface` |
# |                | numeric       |                                | `implant_length_mm`, `implant_diameter_mm` |
# | **surgical**   | binary        | surgical factors               | `bone_augmentation` |
# |                | categorical   |                                | `placement_timing` |
# |                | numeric       |                                | `insertion_torque_ncm` |
# | **prosthetic** | categorical   | prosthetic factors             | `loading_protocol`, `restoration_type` |
# | **target**     | binary        | target variable                | `implant_survival_10y` |

# %%
# =============================
# Generate group + encoding
# =============================
def generate_group_encoding(df, id_cols=None, group_mapping=None):
    if group_mapping is None:
        group_mapping = {}   
    df_copy = df.copy()
    meta_list = []
    for col in df_copy.columns:
        dtype = df_copy[col].dtype
        n_unique = df_copy[col].nunique()
        unique_values = df_copy[col].unique().tolist()
        
        # Encoding types
        if col in id_cols:
            encoding = "id"
        elif dtype == "object":
            encoding = "categorical"
        elif n_unique == 2 and set(df_copy[col].dropna().unique()).issubset({0,1}):
            encoding = "binary"
        else:
            encoding = "numeric"
        # Group types
        group = group_mapping.get(col, None)
        meta_list.append({
            "var": col,
            "dtype": str(dtype),
            "n_unique": n_unique,
            "unique_values": unique_values,
            "encoding": encoding,
            "group": group
        })    
    meta_df = pd.DataFrame(meta_list)
    return meta_df


# Custom group mapping
group_mapping = {
    "patient_id": "id",
    "age": "pt",
    "gender": "pt",
    "smoking_status": "pt",
    "diabetes": "pt",
    "vitamin_d_deficiency": "pt",
    "history_periodontitis": "clinical",
    "bruxism": "clinical",
    "oral_hygiene": "clinical",
    "bone_quality": "clinical",
    "jaw_location": "clinical",
    "implant_length_mm": "implant",
    "implant_diameter_mm": "implant",
    "implant_surface": "implant",
    "placement_timing": "surgical",
    "insertion_torque_ncm": "surgical",
    "bone_augmentation": "surgical",
    "loading_protocol": "prosthetic",
    "restoration_type": "prosthetic",
    "implant_survival_10y": "target"
}


# -----------------------------
# Get group + encodings for train
# -----------------------------
train_group_encoding_df = generate_group_encoding(train_raw, id_cols=["patient_id"],
                                                  group_mapping=group_mapping)


# -----------------------------
# Get group + encodings for test
# -----------------------------
test_group_encoding_df = generate_group_encoding(test_raw, id_cols=["patient_id"],
                                                 group_mapping=group_mapping)

# %%
# =============================
# Slice train by group + encoding
# =============================
train_full = train_raw.copy()

# Create a dict mapping column -> group + encoding
train_col_group = train_group_encoding_df.set_index("var")["group"].to_dict()
train_col_encoding = train_group_encoding_df.set_index("var")["encoding"].to_dict()
train_full._meta_group = train_col_group
train_full._meta_encoding = train_col_encoding

# Dictionary of columns by group & encoding
train_cols_by_group_encoding = {
    (grp, enc): train_group_encoding_df[
        (train_group_encoding_df["group"] == grp) &
        (train_group_encoding_df["encoding"] == enc)
    ]["var"].tolist()
    for grp in train_group_encoding_df["group"].unique()
    for enc in train_group_encoding_df["encoding"].unique()
}


# -----------------------------
# Get train slices
# -----------------------------
# id
train_cols_id_id = train_cols_by_group_encoding.get(("id", "id"), [])

# pt
train_cols_pt_binary = train_cols_by_group_encoding.get(
    ("pt", "binary"), [])
train_cols_pt_categorical = train_cols_by_group_encoding.get(("pt", "categorical"), [])
train_cols_pt_numeric = train_cols_by_group_encoding.get(
    ("pt", "numeric"), [])

# clinical
train_cols_clinical_binary = train_cols_by_group_encoding.get(
    ("clinical", "binary"), [])
train_cols_clinical_categorical = train_cols_by_group_encoding.get(
    ("clinical", "categorical"), [])

# implant
train_cols_implant_categorical = train_cols_by_group_encoding.get(
    ("implant", "categorical"), [])
train_cols_implant_numeric = train_cols_by_group_encoding.get(
    ("implant", "numeric"), [])

# surgical
train_cols_surgical_binary = train_cols_by_group_encoding.get(
    ("surgical", "binary"), [])
train_cols_surgical_categorical = train_cols_by_group_encoding.get(
    ("surgical", "categorical"), [])
train_cols_surgical_numeric = train_cols_by_group_encoding.get(
    ("surgical", "numeric"), [])

# prosthetic
train_cols_prosthetic_categorical = train_cols_by_group_encoding.get(
    ("prosthetic", "categorical"), [])

# target
train_cols_target_target = train_cols_by_group_encoding.get(("target", "binary"), [])

# %%
# =============================
# Slice test by group + encoding
# =============================
test_set = test_raw.copy()

# Create a dict mapping column -> group + encoding
test_col_group = test_group_encoding_df.set_index("var")["group"].to_dict()
test_col_encoding = test_group_encoding_df.set_index("var")["encoding"].to_dict()
test_set._meta_group = test_col_group
test_set._meta_encoding = test_col_encoding

# Dictionary of columns by group & encoding
test_cols_by_group_encoding = {
    (grp, enc): test_group_encoding_df[
        (test_group_encoding_df["group"] == grp) &
        (test_group_encoding_df["encoding"] == enc)
    ]["var"].tolist()
    for grp in test_group_encoding_df["group"].unique()
    for enc in test_group_encoding_df["encoding"].unique()
}


# -----------------------------
# Get test slices
# -----------------------------
# id
test_cols_id_id = test_cols_by_group_encoding.get(("id", "id"), [])

# pt
test_cols_pt_binary = test_cols_by_group_encoding.get(
    ("pt", "binary"), [])
test_cols_pt_categorical = test_cols_by_group_encoding.get(
    ("pt", "categorical"), [])
test_cols_pt_numeric = test_cols_by_group_encoding.get(("pt", "numeric"), [])

# clinical
test_cols_clinical_binary = test_cols_by_group_encoding.get(
    ("clinical", "binary"), [])
test_cols_clinical_categorical = test_cols_by_group_encoding.get(
    ("clinical", "categorical"), [])

# implant
test_cols_implant_categorical = test_cols_by_group_encoding.get(
    ("implant", "categorical"), [])
test_cols_implant_numeric = test_cols_by_group_encoding.get(
    ("implant", "numeric"), [])

# surgical
test_cols_surgical_binary = test_cols_by_group_encoding.get(
    ("surgical", "binary"), [])
test_cols_surgical_categorical = test_cols_by_group_encoding.get(
    ("surgical", "categorical"), [])
test_cols_surgical_numeric = test_cols_by_group_encoding.get(
    ("surgical", "numeric"), [])

# prosthetic
test_cols_prosthetic_categorical = test_cols_by_group_encoding.get(
    ("prosthetic", "categorical"), [])

# %% [markdown]
# ---
# ## Visualize Data
#
# Next, we checked our `train_raw` data to get the counts of implants that failed after 10 years vs. those that survived. Our data reflects the real-world survival rate of
# $\approx {\color{RoyalBlue}{91\%}}$
# mentioned in our problem description. We plotted a bar chart and pie chart to show this distribution.

# %%
# =============================
# Counts of implant survival at 10 years
# =============================
train_full = train_raw.copy()
display(HTML(f"<strong>Train Full Data</strong>"))
train_labels = train_full.columns[-1]
counts = (train_full[train_labels].value_counts().reindex([0, 1]))

# -----------------------------
# Plot implant survival at 10 years
# -----------------------------
fig, axes = plt.subplots(1, 2, figsize=(10, 5))
legend_labels = ["0 = Failed", "1 = Survived"]

# Bar chart
bars = axes[0].bar(counts.index.astype(str), counts.values,
                   color=["LightCoral", "LightSkyBlue"])
axes[0].set_title(f"{train_labels} Distribution (Bar)", weight="bold")
axes[0].set_xlabel(train_labels)
axes[0].set_ylabel("Count")
axes[0].legend(bars, legend_labels)
for bar in bars:
    height = bar.get_height()
    axes[0].annotate(
        f"{height}",
        xy=(bar.get_x() + bar.get_width() / 2, height),
        xytext=(0, 0.5),
        textcoords="offset points",
        ha="center",
        va="bottom",
    )

# Pie chart
axes[1].pie(counts.values, autopct="%1.1f%%",
            colors=["LightCoral", "LightSkyBlue"], labels=legend_labels)
axes[1].set_title(f"{train_labels} Distribution (Pie)", weight="bold")

plt.tight_layout()
plt.show()
# Out:
# <strong>Train Full Data</strong>

# %% [markdown]
# > ---
#
# The next several visualizations plot the counts and distributions of our variables across our train data set. Plots are organized by `group` and `encoding`.

# %%
# =============================
# Visualizations by group + encoding
# =============================

# -----------------------------
# pt
# -----------------------------
# pt : binary — pie charts
display(HTML(f"<strong>Train Full Data &emsp; pt : binary</strong>"))
pt_binary_vars = [
    ("Diabetes", train_cols_pt_binary[0]),
    ("Vitamin D Deficiency", train_cols_pt_binary[1]),
]
fig, axes = plt.subplots(1, len(pt_binary_vars), figsize=(8, 3))
if len(pt_binary_vars) == 1:
    axes = [axes]
for ax, (var_name, col) in zip(axes, pt_binary_vars):
    counts = train_full[col].value_counts().reindex([0,1])
    labels = [f"No {var_name}", f"{var_name}"]
    ax.pie(
        counts,
        labels=[f"{lab}\n{cnt} ({cnt / counts.sum():.1%})"
                for lab, cnt in zip(labels, counts)],
        autopct=None,
        startangle=90
    )
    ax.set_title(var_name, weight="bold")
plt.tight_layout()
plt.show()

# pt : categorical — bar plots
display(HTML(f"<strong>Train Full Data &emsp; pt : categorical</strong>"))
pt_categorical_vars = [
    ("Gender", train_cols_pt_categorical[0]),
    ("Smoking Status", train_cols_pt_categorical[1]),
]
fig, axes = plt.subplots(1, len(pt_categorical_vars), figsize=(12, 4))
if len(pt_categorical_vars) == 1:
    axes = [axes]
for ax, (var_name, col) in zip(axes, pt_categorical_vars):
    counts = train_full[col].value_counts().sort_index()
    total  = counts.sum()
    labels = counts.index.tolist()
    bars = ax.bar(labels, counts)
    for b, cnt in zip(bars, counts):
        ax.text(
            b.get_x() + b.get_width()/2,
            b.get_height(),
            f"{cnt}\n({cnt/total:.1%})",
            ha="center", va="bottom"
        )
    ax.set_title(var_name, weight="bold")
    ax.set_ylabel("Count")
    ax.set_xticklabels(labels, rotation=45)
    ax.set_ylim(0, counts.max() * 1.25)
plt.tight_layout()
plt.show()

# pt : numeric — distribution (histogram + KDE)
display(HTML(f"<strong>Train Full Data &emsp; pt : numeric</strong>"))
pt_numeric_vars = [
    ("Age", train_cols_pt_numeric[0]),
]
fig, axes = plt.subplots(1, len(pt_numeric_vars), figsize=(14, 4))
if len(pt_numeric_vars) == 1:
    axes = [axes]
for ax, (var_name, col) in zip(axes, pt_numeric_vars):
    data = train_full[col].dropna()
    ax.hist(data, bins=20, density=True, alpha=0.6)
    kde = data.plot(kind="kde", ax=ax, linewidth=2)
    ax.set_title(var_name, weight="bold")
    ax.set_xlabel("Value")
    ax.set_ylabel("Density")
    ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()


display(HTML(f"<br><br><blockquote><hr></blockquote>"))


# -----------------------------
# clinical
# -----------------------------
# clinical : binary — pie charts
display(HTML(f"<br><br><strong>Train Full Data &emsp; clinical : binary</strong>"))
clinical_binary_vars = [
    ("History Periodontitis", train_cols_clinical_binary[0]),
    ("Bruxism", train_cols_clinical_binary[1]),
]
fig, axes = plt.subplots(1, len(clinical_binary_vars), figsize=(8, 3))
if len(clinical_binary_vars) == 1:
    axes = [axes]
for ax, (var_name, col) in zip(axes, clinical_binary_vars):
    counts = train_full[col].value_counts().reindex([0,1])
    labels = [f"No {var_name}", f"{var_name}"]
    ax.pie(
        counts,
        labels=[f"{lab}\n{cnt} ({cnt / counts.sum():.1%})"
                for lab, cnt in zip(labels, counts)],
        autopct=None,
        startangle=90
    )
    ax.set_title(var_name, weight="bold")
plt.tight_layout()
plt.show()

# clinical : categorical — bar plots
display(HTML(f"<strong>Train Full Data &emsp; clinical : categorical</strong>"))
clinical_categorical_vars = [
    ("Oral Hygiene", train_cols_clinical_categorical[0]),
    ("Bone Quality", train_cols_clinical_categorical[1]),
    ("Jaw Location", train_cols_clinical_categorical[2]),
]
fig, axes = plt.subplots(1, len(clinical_categorical_vars), figsize=(12, 4))
if len(clinical_categorical_vars) == 1:
    axes = [axes]
for ax, (var_name, col) in zip(axes, clinical_categorical_vars):
    counts = train_full[col].value_counts().sort_index()
    total  = counts.sum()
    labels = counts.index.tolist()
    bars = ax.bar(labels, counts)
    for b, cnt in zip(bars, counts):
        ax.text(
            b.get_x() + b.get_width()/2,
            b.get_height(),
            f"{cnt}\n({cnt/total:.1%})",
            ha="center", va="bottom"
        )
    ax.set_title(var_name, weight="bold")
    ax.set_ylabel("Count")
    ax.set_xticklabels(labels, rotation=45)
    ax.set_ylim(0, counts.max() * 1.25)
plt.tight_layout()
plt.show()


display(HTML(f"<br><br><blockquote><hr></blockquote>"))


# -----------------------------
# implant
# -----------------------------
# implant : categorical — bar plots
display(HTML(f"<br><br><strong>Train Full Data &emsp; implant : categorical</strong>"))
implant_categorical_vars = [
    ("Implant Surface", train_cols_implant_categorical[0]),
]
fig, axes = plt.subplots(1, len(implant_categorical_vars), figsize=(12, 4))
if len(implant_categorical_vars) == 1:
    axes = [axes]
for ax, (var_name, col) in zip(axes, implant_categorical_vars):
    counts = train_full[col].value_counts().sort_index()
    total  = counts.sum()
    labels = counts.index.tolist()
    bars = ax.bar(labels, counts)
    for b, cnt in zip(bars, counts):
        ax.text(
            b.get_x() + b.get_width()/2,
            b.get_height(),
            f"{cnt}\n({cnt/total:.1%})",
            ha="center", va="bottom"
        )
    ax.set_title(var_name, weight="bold")
    ax.set_ylabel("Count")
    ax.set_xticklabels(labels, rotation=45)
    ax.set_ylim(0, counts.max() * 1.25)
plt.tight_layout()
plt.show()

# pt : implant — distribution (histogram + KDE)
display(HTML(f"<strong>Train Full Data &emsp; implant : numeric</strong>"))
implant_numeric_vars = [
    ("Implant Length, mm", train_cols_implant_numeric[0]),
    ("Implant Diameter, mm", train_cols_implant_numeric[1]),
]
fig, axes = plt.subplots(1, len(implant_numeric_vars), figsize=(14, 4))
if len(implant_numeric_vars) == 1:
    axes = [axes]
for ax, (var_name, col) in zip(axes, implant_numeric_vars):
    data = train_full[col].dropna()
    ax.hist(data, bins=20, density=True, alpha=0.6)
    kde = data.plot(kind="kde", ax=ax, linewidth=2)
    ax.set_title(var_name, weight="bold")
    ax.set_xlabel("Value")
    ax.set_ylabel("Density")
    ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()


display(HTML(f"<br><br><blockquote><hr></blockquote>"))


# -----------------------------
# surgical
# -----------------------------
# surgical : binary — pie charts
display(HTML(f"<br><br><strong>Train Full Data &emsp; surgical : binary</strong>"))
surgical_binary_vars = [
    ("Bone Augmentation", train_cols_surgical_binary[0]),
]
fig, axes = plt.subplots(1, len(surgical_binary_vars), figsize=(8, 3))
if len(surgical_binary_vars) == 1:
    axes = [axes]
for ax, (var_name, col) in zip(axes, surgical_binary_vars):
    counts = train_full[col].value_counts().reindex([0,1])
    labels = [f"No {var_name}", f"{var_name}"]
    ax.pie(
        counts,
        labels=[f"{lab}\n{cnt} ({cnt / counts.sum():.1%})"
                for lab, cnt in zip(labels, counts)],
        autopct=None,
        startangle=90
    )
    ax.set_title(var_name, weight="bold")
plt.tight_layout()
plt.show()

# surgical : categorical — bar plots
display(HTML(f"<strong>Train Full Data &emsp; surgical : categorical</strong>"))
surgical_categorical_vars = [
    ("Placement Timing", train_cols_surgical_categorical[0]),
]
fig, axes = plt.subplots(1, len(surgical_categorical_vars), figsize=(12, 4))
if len(surgical_categorical_vars) == 1:
    axes = [axes]
for ax, (var_name, col) in zip(axes, surgical_categorical_vars):
    counts = train_full[col].value_counts().sort_index()
    total  = counts.sum()
    labels = counts.index.tolist()
    bars = ax.bar(labels, counts)
    for b, cnt in zip(bars, counts):
        ax.text(
            b.get_x() + b.get_width()/2,
            b.get_height(),
            f"{cnt}\n({cnt/total:.1%})",
            ha="center", va="bottom"
        )
    ax.set_title(var_name, weight="bold")
    ax.set_ylabel("Count")
    ax.set_xticklabels(labels, rotation=45)
    ax.set_ylim(0, counts.max() * 1.25)
plt.tight_layout()
plt.show()

# surgical : numeric — distribution (histogram + KDE)
display(HTML(f"<strong>Train Full Data &emsp; surgical : numeric</strong>"))
surgical_numeric_vars = [
    ("Insertion Torgue, ncm", train_cols_surgical_numeric[0]),
]
fig, axes = plt.subplots(1, len(surgical_numeric_vars), figsize=(14, 4))
if len(surgical_numeric_vars) == 1:
    axes = [axes]
for ax, (var_name, col) in zip(axes, surgical_numeric_vars):
    data = train_full[col].dropna()
    ax.hist(data, bins=20, density=True, alpha=0.6)
    kde = data.plot(kind="kde", ax=ax, linewidth=2)
    ax.set_title(var_name, weight="bold")
    ax.set_xlabel("Value")
    ax.set_ylabel("Density")
    ax.grid(alpha=0.3)
plt.tight_layout()
plt.show()


display(HTML(f"<br><br><blockquote><hr></blockquote>"))


# -----------------------------
# protesthetic
# -----------------------------
# prosthetic : categorical — bar plots
display(HTML(f"<br><br><strong>Train Full Data &emsp; prosthetic : categorical</strong>"))
prosthetic_categorical_vars = [
    ("Loading Protocol", train_cols_prosthetic_categorical[0]),
    ("Restoration Type", train_cols_prosthetic_categorical[1]),
]
fig, axes = plt.subplots(1, len(prosthetic_categorical_vars), figsize=(12, 4))
if len(prosthetic_categorical_vars) == 1:
    axes = [axes]
for ax, (var_name, col) in zip(axes, prosthetic_categorical_vars):
    counts = train_full[col].value_counts().sort_index()
    total  = counts.sum()
    labels = counts.index.tolist()
    bars = ax.bar(labels, counts)
    for b, cnt in zip(bars, counts):
        ax.text(
            b.get_x() + b.get_width()/2,
            b.get_height(),
            f"{cnt}\n({cnt/total:.1%})",
            ha="center", va="bottom"
        )
    ax.set_title(var_name, weight="bold")
    ax.set_ylabel("Count")
    ax.set_xticklabels(labels, rotation=45)
    ax.set_ylim(0, counts.max() * 1.25)
plt.tight_layout()
plt.show()
# Out:
# <strong>Train Full Data &emsp; pt : binary</strong>
# <strong>Train Full Data &emsp; pt : categorical</strong>
# <strong>Train Full Data &emsp; pt : numeric</strong>
# <br><br><blockquote><hr></blockquote>
# <br><br><strong>Train Full Data &emsp; clinical : binary</strong>
# <strong>Train Full Data &emsp; clinical : categorical</strong>
# <br><br><blockquote><hr></blockquote>
# <br><br><strong>Train Full Data &emsp; implant : categorical</strong>
# <strong>Train Full Data &emsp; implant : numeric</strong>
# <br><br><blockquote><hr></blockquote>
# <br><br><strong>Train Full Data &emsp; surgical : binary</strong>
# <strong>Train Full Data &emsp; surgical : categorical</strong>
# <strong>Train Full Data &emsp; surgical : numeric</strong>
# <br><br><blockquote><hr></blockquote>
# <br><br><strong>Train Full Data &emsp; prosthetic : categorical</strong>

# %% [markdown]
# > ---
#
# From here, we split our sliced up train data into a train set and a validation set. We also created a test set out of our sliced test data.

# %%
# =============================
# Train + Val Split
# =============================
train_set, val_set = train_test_split(
    train_full,
    test_size=0.2,
    random_state=86,
    # Stratify on target (implant_survival_10y)
    stratify=train_full["implant_survival_10y"]
)

# Feature metadata with group + encoding
feature_meta = train_group_encoding_df.set_index("var").drop((), errors="ignore")

# Scaler for numeric features
scaler = StandardScaler()
numeric_cols = train_cols_pt_numeric + train_cols_implant_numeric + train_cols_surgical_numeric


# -----------------------------
# Train Set
# -----------------------------
X_train = train_set.drop(columns=["implant_survival_10y", "patient_id"])
# One-hot encoding
X_train_enc = pd.get_dummies(X_train, columns=train_cols_pt_categorical + 
                                          train_cols_clinical_categorical + 
                                          train_cols_implant_categorical + 
                                          train_cols_surgical_categorical +
                                          train_cols_prosthetic_categorical)
X_train_enc[numeric_cols] = scaler.fit_transform(X_train_enc[numeric_cols])
X_train_enc = X_train_enc.astype("float32")
y_train = train_set["implant_survival_10y"]
display(HTML(f"<strong>Train Set</strong>"))
print(f"Size:    {train_set.shape[0]} rows × {train_set.shape[1]} columns")
print(train_set["implant_survival_10y"].value_counts(normalize=True))


# -----------------------------
# Valid Set
# -----------------------------
X_val = val_set.drop(columns=["implant_survival_10y", "patient_id"])
# One-hot encoding
X_val_enc = pd.get_dummies(X_val, columns=train_cols_pt_categorical + 
                                        train_cols_clinical_categorical + 
                                        train_cols_implant_categorical + 
                                        train_cols_surgical_categorical +
                                        train_cols_prosthetic_categorical)
X_val_enc[numeric_cols] = scaler.transform(X_val_enc[numeric_cols])
X_val_enc = X_val_enc.reindex(columns=X_train_enc.columns, fill_value=0)
X_val_enc   = X_val_enc.astype("float32")
y_val = val_set["implant_survival_10y"]
display(HTML(f"<br><strong>Val Set</strong>"))
print(f"Size:    {val_set.shape[0]} rows × {val_set.shape[1]} columns")
print(train_set["implant_survival_10y"].value_counts(normalize=True))

# -----------------------------
# Test Set
# -----------------------------
X_test = test_set.drop(columns=["patient_id"])
# One-hot encoding
X_test_enc = pd.get_dummies(X_test, columns=test_cols_pt_categorical + 
                                        test_cols_clinical_categorical + 
                                        test_cols_implant_categorical + 
                                        test_cols_surgical_categorical +
                                        test_cols_prosthetic_categorical)
X_test_enc[numeric_cols] = scaler.transform(X_test_enc[numeric_cols])
X_test_enc  = X_test_enc.astype("float32")
display(HTML(f"<br><strong>Test Set</strong>"))
print(f"Size:    {test_set.shape[0]} rows × {test_set.shape[1]} columns")
# Out:
# <strong>Train Set</strong>
# Size:    5600 rows × 20 columns
# implant_survival_10y
# 1    0.909643
# 0    0.090357
# Name: proportion, dtype: float64
# <br><strong>Val Set</strong>
# Size:    1400 rows × 20 columns
# implant_survival_10y
# 1    0.909643
# 0    0.090357
# Name: proportion, dtype: float64
# <br><strong>Test Set</strong>
# Size:    3000 rows × 19 columns

# %% [markdown]
# <br>
#
# ---
# ---
# # **3.  Model Architecture**
#
# ---
# ## Define Parameters
#
# We will be testing our models against these hyperparameters
#
# | **dropout_rate <br>(from MLP)** | **learning_rate <br>(from Adam optimizer)**           |
# |:--------------------------------|:------------------------------------------------------|
# | ${\color{Gray}{0.2}}$           | ${\color{HotPink}{\eta}} = {\color{HotPink}{0.001}}$  |
# | ${\color{Gray}{0.2}}$           | ${\color{HotPink}{\eta}} = {\color{HotPink}{0.0005}}$ |
# | ${\color{Gray}{0.3}}$           | ${\color{HotPink}{\eta}} = {\color{HotPink}{0.001}}$  |
# | ${\color{Gray}{0.3}}$           | ${\color{HotPink}{\eta}} = {\color{HotPink}{0.0005}}$ |
#
# Because our data was stratitifed to reflect the highly uneven real-world distribution of implant survival rates at 10 years
# (${\color{Crimson}{9 \%}}$ failure
# vs.
# ${\color{RoyalBlue}{91 \%}}$ survival),
# we create a `class_weights_dictionary` to balance this out.

# %%
# -------------------------
# Class weights dictionary
# -------------------------
class_weights = class_weight.compute_class_weight(
    class_weight="balanced",
    classes=np.unique(y_train),
    y=y_train
)
class_weights_dict = dict(enumerate(class_weights))

# %% [markdown]
# ---
# ## General MLP Model Architecture
#
# From here, we developed a series of MLP models, each with varying numbers of hidden units in their
# ${\color{CornflowerBlue}{\textsf{Dense Layers}}}$.
#
#   * MLP 1: &emsp;
#     ${\color{CornflowerBlue}{h}}_{1}
#         = [ {\color{CornflowerBlue}{256}}, {\color{CornflowerBlue}{128}} ]$
#   * MLP 2: &emsp;
#     ${\color{CornflowerBlue}{h}}_{2}
#         = [ {\color{CornflowerBlue}{64}}, {\color{CornflowerBlue}{32}} ]$
#   * MLP 3: &emsp;
#     ${\color{CornflowerBlue}{h}}_{3}
#         = [ {\color{CornflowerBlue}{16}}, {\color{CornflowerBlue}{8}} ]$
#   * MLP 4: &emsp;
#     ${\color{CornflowerBlue}{h}}_{4}
#         = [ {\color{CornflowerBlue}{4}}, {\color{CornflowerBlue}{2}} ]$
#
# All versions of our model have ${\color{ForestGreen}{n}
#     = \color{ForestGreen}{7}}$
# layers, listed below. The
# ${\color{MediumSeaGreen}{2 \textsf{ non-trainable layers}}}$
# are marked in MediumSeaGreen, and the
# ${\color{CornflowerBlue}{5 \textsf{ trainable layers}}}$
# are marked in CornflowerBlue. Differences between models are found in the number of hidden states
# (${\color{CornflowerBlue}{h}}$)
# in their dense layers.
#
# > 0. ${\color{MediumSeaGreen}{\texttt{Input Layer}}}$ <br>
# >    Receives all input features.
# >
# > 1. ${\color{CornflowerBlue}{\texttt{Dense Layer 1 }}}
#         ( {\color{CornflowerBlue}{h}}_{{\color{Gray}{i}} \, (1)}
#             {\color{CornflowerBlue}{\textsf{ units}}} )$ <br>
# >    First fully connected layer with
#      ${\color{CornflowerBlue}{h}}_{{\color{Gray}{i}} \, (1)}$
#      hidden states. Uses the activation function "ReLU" and L2 regularization to shrink weights and reduce overfitting. Its role is to learn the first level of non-linear feature interactions between our variables.
# >
# > 2. ${\color{CornflowerBlue}{\texttt{Batch Normalization 1}}}$ <br>
# >    Normalizes activations from the previous dense layer. Stabilizes training in small datasets like ours.
# >
# > 3. ${\color{MediumSeaGreen}{\texttt{Dropout 1}}}$ <br>
# >    Regularization layer to prevent overfitting. Dropout rate of
#      $[ {\color{Gray}{0.2}}, \; {\color{Gray}{0.3}} ]$
#      is applied here, depending on iteration.
# >
# > 4. ${\color{CornflowerBlue}{\texttt{Dense Layer 2 }}}
#         ( {\color{CornflowerBlue}{h}}_{{\color{Gray}{i}} \, (2)}
#             {\color{CornflowerBlue}{\textsf{ units}}} )$ <br>
# >    Second fully connected layer with
#      ${\color{CornflowerBlue}{h}}_{{\color{Gray}{i}} \, (2)}$
#      hidden states. Works the same way as the previous dense layer and goes deeper on non-linear feature interactions between our variables.
# >
# > 5. ${\color{CornflowerBlue}{\texttt{Batch Normalization 2}}}$ <br>
# >    Normalizes activations from the previous dense layer.
# >
# > 6. ${\color{MediumSeaGreen}{\texttt{Dropout 2}}}$ <br>
# >    Regularization layer to prevent overfitting. Dropout rate of
#      $[ {\color{Gray}{0.2}}, \; {\color{Gray}{0.3}} ]$
#      is applied here, depending on iteration.
# >
# > 7. ${\color{CornflowerBlue}{\texttt{Output Layer}}}$ <br>
# >    Single dense neuron that uses the sigmoid activation function to give an output between $0$ and $1$ representing the probability of implant survival at 10 years.
#
# We compile our model using the following:
# * **Optimizer:** Adam. Learning rate
#   ${\color{HotPink}{\eta}}
#       = [ {\color{HotPink}{0.001}}, {\color{HotPink}{0.0005}} ]$
#   is applied here, depending on iteration.
# * **Loss Function:** `binary_crossentropy` (because we're expecting binary output)
# * **Metrics:** ROC-AUC, F1-score

# %%
# =========================
# MLP 1;    h = [256, 128]
# =========================
def build_mlp_1(input_shape, hidden_units=[256, 128], dropout=0.3, l2_reg=1e-4):

    # 0. Input Layer
    inp = Input(shape=(input_shape,), name="mlp_input")
    x = inp
    
    for idx, i in enumerate(hidden_units):
        # 1, 4. Dense Layer
        x = Dense(i, activation="relu", kernel_regularizer=l2(l2_reg))(x)
        
        # 2, 5. Batch Normalization
        x = BatchNormalization()(x)
        
        # 3, 6. Dropout 
        x = Dropout(dropout)(x)

    # 7. Output Layer
    out = Dense(1, activation="sigmoid", name="out")(x)
    
    model = Model(inp, out, name="MLP")
    model.compile(optimizer=Adam(learning_rate=1e-3),
                  loss="binary_crossentropy",
                  metrics=[tf.keras.metrics.AUC(name="auc"), "accuracy",
                           Precision(name="prec"), Recall(name="rec")])
    return model

# %%
# =========================
# MLP 2,    h = [64, 32]
# =========================
def build_mlp_2(input_shape, hidden_units=[64, 32], dropout=0.3, l2_reg=1e-4):

    # 0. Input Layer
    inp = Input(shape=(input_shape,), name="mlp_input")
    x = inp
    
    for idx, i in enumerate(hidden_units):
        # 1, 4. Dense Layer
        x = Dense(i, activation="relu", kernel_regularizer=l2(l2_reg))(x)
        
        # 2, 5. Batch Normalization
        x = BatchNormalization()(x)
        
        # 3, 6. Dropout 
        x = Dropout(dropout)(x)

    # 7. Output Layer
    out = Dense(1, activation="sigmoid", name="out")(x)
    
    model = Model(inp, out, name="MLP")
    model.compile(optimizer=Adam(learning_rate=1e-3),
                  loss="binary_crossentropy",
                  metrics=[tf.keras.metrics.AUC(name="auc"), "accuracy",
                           Precision(name="prec"), Recall(name="rec")])
    return model

# %%
# =========================
# MLP 3,    h = [16, 8]
# =========================
def build_mlp_3(input_shape, hidden_units=[16, 8], dropout=0.3, l2_reg=1e-4):

    # 0. Input Layer
    inp = Input(shape=(input_shape,), name="mlp_input")
    x = inp
    
    for idx, i in enumerate(hidden_units):
        # 1, 4. Dense Layer
        x = Dense(i, activation="relu", kernel_regularizer=l2(l2_reg))(x)
        
        # 2, 5. Batch Normalization
        x = BatchNormalization()(x)
        
        # 3, 6. Dropout 
        x = Dropout(dropout)(x)

    # 7. Output Layer
    out = Dense(1, activation="sigmoid", name="out")(x)
    
    model = Model(inp, out, name="MLP")
    model.compile(optimizer=Adam(learning_rate=1e-3),
                  loss="binary_crossentropy",
                  metrics=[tf.keras.metrics.AUC(name="auc"), "accuracy",
                           Precision(name="prec"), Recall(name="rec")])
    return model

# %%
# =========================
# MLP 4,    h = [4, 2]
# =========================
def build_mlp_4(input_shape, hidden_units=[4, 2], dropout=0.3, l2_reg=1e-4):

    # 0. Input Layer
    inp = Input(shape=(input_shape,), name="mlp_input")
    x = inp
    
    for idx, i in enumerate(hidden_units):
        # 1, 4. Dense Layer
        x = Dense(i, activation="relu", kernel_regularizer=l2(l2_reg))(x)
        
        # 2, 5. Batch Normalization
        x = BatchNormalization()(x)
        
        # 3, 6. Dropout 
        x = Dropout(dropout)(x)

    # 7. Output Layer
    out = Dense(1, activation="sigmoid", name="out")(x)
    
    model = Model(inp, out, name="MLP")
    model.compile(optimizer=Adam(learning_rate=1e-3),
                  loss="binary_crossentropy",
                  metrics=[tf.keras.metrics.AUC(name="auc"), "accuracy",
                           Precision(name="prec"), Recall(name="rec")])
    return model

# %% [markdown]
# <br>
#
# ---
# ---
# # **4.  Results and Analysis**
#
# ---
# We ran our each of our MLP models across
# ${\color{Sienna}{k}}
#     = {\color{Sienna}{80}}$
# epochs, but applied `tf.keras.callbacks.EarlyStopping()` to avoid overfitting. We also applied a
# ${\color{Sienna}{k}}
#     = {\color{Sienna}{5}}$ cross-fold validation to deal with overfitting on our small dataset.
#
# For each of our parameter groups, we chose the model iterations that would give us the best validation set ROC-AUC score and plotted them below. Our train set is plotted in RoyalBlue and our validation set is plotted in Crimson. ROC-AUC scores are marked with a circle and dashed lines, while F1-scores are marked with a square and solid lines. We highlighted the values for the best model in Plum.

# %% [markdown]
# ---
# ## MLP 1, &ensp; $h = [256, 128]$
#
# We found our highest validation set ROC-AUC score when our dropout rate was set to
# ${\color{Gray}{0.2}}$
# and our learning rate was set to
# ${\color{HotPink}{\eta}}
#     = {\color{HotPink}{0.0005}}$.
#
# However, the ROC-AUC score for our train set was almost always around
# $1.0$,
# while it hovered around
# $0.53$
# for our validation set. This tells us our model was badly overfitting.

# %%
# =========================
# Tuning MLP 1 on 5-fold CV
# =========================
dropouts = [0.2, 0.3]
learning_rates = [0.001, 0.0005]
k_folds = 5

mlp_1_cv_summary = []

skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=random_state)

for do in dropouts:
    for lr in learning_rates:
        display(HTML(f"<br><strong>Training MLP 1, &ensp; h = [256, 128]"
                     f"&ensp; with dropout={do}, lr={lr}</strong><br>"))        
        
        fold_train_roc_auc = []
        fold_val_roc_auc = []
        fold_train_f1 = []
        fold_val_f1 = []

        for fold, (train_idx, val_idx) in enumerate(skf.split(X_train_enc, y_train)):
            X_tr, X_val = X_train_enc.iloc[train_idx], X_train_enc.iloc[val_idx]
            y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]

            # Build & compile model
            model = build_mlp_1(input_shape=X_train_enc.shape[1], dropout=do)
            model.compile(optimizer=Adam(learning_rate=lr),
                          loss="binary_crossentropy",
                          metrics=[tf.keras.metrics.AUC(name="auc"),
                                   Precision(name="prec"),
                                   Recall(name="rec")])

            early_stop = EarlyStopping(
            monitor="val_roc_auc",
            patience=8,
            mode="max",
            restore_best_weights=True
            )
            
            # Train
            history = model.fit(
                X_tr, y_tr,
                validation_data=(X_val, y_val),
                epochs=80,
                batch_size=64,
                verbose=0,
                class_weight=class_weights_dict,
                callbacks=[early_stop] 
            )

            # Predict
            train_probs = model.predict(X_tr, verbose=0).flatten()
            val_probs = model.predict(X_val, verbose=0).flatten()
            train_preds = (train_probs > 0.5).astype(int)
            val_preds = (val_probs > 0.5).astype(int)

            # Compute metrics
            tr_roc_auc = roc_auc_score(y_tr, train_probs)
            val_roc_auc = roc_auc_score(y_val, val_probs)
            tr_f1 = f1_score(y_tr, train_preds)
            val_f1 = f1_score(y_val, val_preds)
            
            fold_train_roc_auc.append(tr_roc_auc)
            fold_val_roc_auc.append(val_roc_auc)
            fold_train_f1.append(tr_f1)
            fold_val_f1.append(val_f1)

            # Track best ROC-AUC for this fold
            print(f"\nFold {fold+1}:")
            print(f"   Train ROC-AUC: {tr_roc_auc:.4f} | Train F1: {tr_f1:.4f}")
            print(f"   Val   ROC-AUC: {val_roc_auc:.4f} | Val   F1: {val_f1:.4f}")

            # Confusion matrix for this fold
            cm = confusion_matrix(y_val, val_preds)
            print("    Confusion Matrix (Val):")
            print(cm)

        # Save mean metrics across folds
        mlp_1_cv_summary.append({
            "dropout_rate": do,
            "lr": lr,
            "train_roc_auc_mean": np.mean(fold_train_roc_auc),
            "val_roc_auc_mean": np.mean(fold_val_roc_auc),
            "train_f1_mean": np.mean(fold_train_f1),
            "val_f1_mean": np.mean(fold_val_f1),
        })

# Convert to DataFrame
mlp_1_cv_df = pd.DataFrame(mlp_1_cv_summary)

# Highlight best mean val ROC-AUC
def highlight_best_val_roc_auc(row):
    if row["val_roc_auc_mean"] == mlp_1_cv_df["val_roc_auc_mean"].max():
        return ["background-color: #F4DCF3"]*len(row)
    return [""]*len(row)


display(HTML(f"<br><strong>Training MLP 1, &ensp; h = [256, 128]"
                     f"&ensp; HyperParameter Summary</strong><br>"))  
display(mlp_1_cv_df.style.apply(highlight_best_val_roc_auc, axis=1))
# Out:
# <br><strong>Training MLP 1, &ensp; h = [256, 128]&ensp; with dropout=0.2, lr=0.001</strong><br>
# 2025-12-09 01:59:07.880966: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:152] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: UNKNOWN ERROR (303)
# Fold 1:
#    Train ROC-AUC: 0.9998 | Train F1: 0.9967
#    Val   ROC-AUC: 0.5504 | Val   F1: 0.9189
#     Confusion Matrix (Val):
# [[  7  94]
#  [ 73 946]]
#
# Fold 2:
#    Train ROC-AUC: 0.9997 | Train F1: 0.9913
#    Val   ROC-AUC: 0.4748 | Val   F1: 0.9032
#     Confusion Matrix (Val):
# [[ 10  91]
#  [105 914]]
#
# Fold 3:
#    Train ROC-AUC: 1.0000 | Train F1: 0.9961
#    Val   ROC-AUC: 0.4955 | Val   F1: 0.9132
#     Confusion Matrix (Val):
# [[  6  95]
#  [ 83 936]]
#
# Fold 4:
#    Train ROC-AUC: 0.9997 | Train F1: 0.9920
#    Val   ROC-AUC: 0.4870 | Val   F1: 0.8983
#     Confusion Matrix (Val):
# [[ 10  91]
#  [114 905]]
#
# Fold 5:
#    Train ROC-AUC: 1.0000 | Train F1: 0.9959
#    Val   ROC-AUC: 0.5390 | Val   F1: 0.9145
#     Confusion Matrix (Val):
# [[ 16  86]
#  [ 88 930]]
# <br><strong>Training MLP 1, &ensp; h = [256, 128]&ensp; with dropout=0.2, lr=0.0005</strong><br>
# Fold 1:
#    Train ROC-AUC: 1.0000 | Train F1: 0.9959
#    Val   ROC-AUC: 0.5437 | Val   F1: 0.9172
#     Confusion Matrix (Val):
# [[  8  93]
#  [ 77 942]]
#
# Fold 2:
#    Train ROC-AUC: 1.0000 | Train F1: 0.9942
#    Val   ROC-AUC: 0.4951 | Val   F1: 0.8993
#     Confusion Matrix (Val):
# [[ 11  90]
#  [113 906]]
#
# Fold 3:
#    Train ROC-AUC: 1.0000 | Train F1: 0.9938
#    Val   ROC-AUC: 0.5257 | Val   F1: 0.9070
#     Confusion Matrix (Val):
# [[  9  92]
#  [ 97 922]]
#
# Fold 4:
#    Train ROC-AUC: 0.9999 | Train F1: 0.9940
#    Val   ROC-AUC: 0.5501 | Val   F1: 0.9120
#     Confusion Matrix (Val):
# [[ 14  87]
#  [ 92 927]]
#
# Fold 5:
#    Train ROC-AUC: 0.9999 | Train F1: 0.9957
#    Val   ROC-AUC: 0.5758 | Val   F1: 0.9073
#     Confusion Matrix (Val):
# [[ 24  78]
#  [108 910]]
# <br><strong>Training MLP 1, &ensp; h = [256, 128]&ensp; with dropout=0.3, lr=0.001</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.9995 | Train F1: 0.9908
#    Val   ROC-AUC: 0.5263 | Val   F1: 0.9084
#     Confusion Matrix (Val):
# [[ 12  89]
#  [ 97 922]]
#
# Fold 2:
#    Train ROC-AUC: 0.9999 | Train F1: 0.9910
#    Val   ROC-AUC: 0.5214 | Val   F1: 0.8957
#     Confusion Matrix (Val):
# [[  8  93]
#  [117 902]]
#
# Fold 3:
#    Train ROC-AUC: 0.9996 | Train F1: 0.9897
#    Val   ROC-AUC: 0.5489 | Val   F1: 0.9008
#     Confusion Matrix (Val):
# [[ 12  89]
#  [111 908]]
#
# Fold 4:
#    Train ROC-AUC: 0.9998 | Train F1: 0.9897
#    Val   ROC-AUC: 0.4989 | Val   F1: 0.9021
#     Confusion Matrix (Val):
# [[ 10  91]
#  [107 912]]
#
# Fold 5:
#    Train ROC-AUC: 0.9999 | Train F1: 0.9932
#    Val   ROC-AUC: 0.5456 | Val   F1: 0.9093
#     Confusion Matrix (Val):
# [[ 14  88]
#  [ 96 922]]
# <br><strong>Training MLP 1, &ensp; h = [256, 128]&ensp; with dropout=0.3, lr=0.0005</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.9996 | Train F1: 0.9852
#    Val   ROC-AUC: 0.5252 | Val   F1: 0.9025
#     Confusion Matrix (Val):
# [[ 11  90]
#  [107 912]]
#
# Fold 2:
#    Train ROC-AUC: 0.9994 | Train F1: 0.9896
#    Val   ROC-AUC: 0.4884 | Val   F1: 0.9014
#     Confusion Matrix (Val):
# [[ 11  90]
#  [109 910]]
#
# Fold 3:
#    Train ROC-AUC: 0.9995 | Train F1: 0.9878
#    Val   ROC-AUC: 0.5495 | Val   F1: 0.9058
#     Confusion Matrix (Val):
# [[ 11  90]
#  [101 918]]
#
# Fold 4:
#    Train ROC-AUC: 0.9997 | Train F1: 0.9866
#    Val   ROC-AUC: 0.5356 | Val   F1: 0.9069
#     Confusion Matrix (Val):
# [[ 16  85]
#  [103 916]]
#
# Fold 5:
#    Train ROC-AUC: 0.9994 | Train F1: 0.9840
#    Val   ROC-AUC: 0.5809 | Val   F1: 0.9013
#     Confusion Matrix (Val):
# [[ 24  78]
#  [119 899]]
# <br><strong>Training MLP 1, &ensp; h = [256, 128]&ensp; HyperParameter Summary</strong><br>
# <style type="text/css">
# #T_a3aa8_row1_col0, #T_a3aa8_row1_col1, #T_a3aa8_row1_col2, #T_a3aa8_row1_col3, #T_a3aa8_row1_col4, #T_a3aa8_row1_col5 {
#   background-color: #F4DCF3;
# }
# </style>
# <table id="T_a3aa8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3aa8_level0_col0" class="col_heading level0 col0" >dropout_rate</th>
#       <th id="T_a3aa8_level0_col1" class="col_heading level0 col1" >lr</th>
#       <th id="T_a3aa8_level0_col2" class="col_heading level0 col2" >train_roc_auc_mean</th>
#       <th id="T_a3aa8_level0_col3" class="col_heading level0 col3" >val_roc_auc_mean</th>
#       <th id="T_a3aa8_level0_col4" class="col_heading level0 col4" >train_f1_mean</th>
#       <th id="T_a3aa8_level0_col5" class="col_heading level0 col5" >val_f1_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3aa8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a3aa8_row0_col0" class="data row0 col0" >0.200000</td>
#       <td id="T_a3aa8_row0_col1" class="data row0 col1" >0.001000</td>
#       <td id="T_a3aa8_row0_col2" class="data row0 col2" >0.999814</td>
#       <td id="T_a3aa8_row0_col3" class="data row0 col3" >0.509323</td>
#       <td id="T_a3aa8_row0_col4" class="data row0 col4" >0.994393</td>
#       <td id="T_a3aa8_row0_col5" class="data row0 col5" >0.909589</td>
#     </tr>
#     <tr>
#       <th id="T_a3aa8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a3aa8_row1_col0" class="data row1 col0" >0.200000</td>
#       <td id="T_a3aa8_row1_col1" class="data row1 col1" >0.000500</td>
#       <td id="T_a3aa8_row1_col2" class="data row1 col2" >0.999967</td>
#       <td id="T_a3aa8_row1_col3" class="data row1 col3" >0.538070</td>
#       <td id="T_a3aa8_row1_col4" class="data row1 col4" >0.994720</td>
#       <td id="T_a3aa8_row1_col5" class="data row1 col5" >0.908551</td>
#     </tr>
#     <tr>
#       <th id="T_a3aa8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a3aa8_row2_col0" class="data row2 col0" >0.300000</td>
#       <td id="T_a3aa8_row2_col1" class="data row2 col1" >0.001000</td>
#       <td id="T_a3aa8_row2_col2" class="data row2 col2" >0.999728</td>
#       <td id="T_a3aa8_row2_col3" class="data row2 col3" >0.528207</td>
#       <td id="T_a3aa8_row2_col4" class="data row2 col4" >0.990886</td>
#       <td id="T_a3aa8_row2_col5" class="data row2 col5" >0.903249</td>
#     </tr>
#     <tr>
#       <th id="T_a3aa8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a3aa8_row3_col0" class="data row3 col0" >0.300000</td>
#       <td id="T_a3aa8_row3_col1" class="data row3 col1" >0.000500</td>
#       <td id="T_a3aa8_row3_col2" class="data row3 col2" >0.999515</td>
#       <td id="T_a3aa8_row3_col3" class="data row3 col3" >0.535932</td>
#       <td id="T_a3aa8_row3_col4" class="data row3 col4" >0.986643</td>
#       <td id="T_a3aa8_row3_col5" class="data row3 col5" >0.903583</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ========================
# Plot MLP 1 CV Results
# ========================
mlp_1_cv_df["label"] = mlp_1_cv_df.apply(
    lambda row: f"drop={row['dropout_rate']}, lr={row['lr']}", axis=1
)

x = range(len(mlp_1_cv_df))
plt.figure(figsize=(10,6))

# Train metrics
plt.plot(x, mlp_1_cv_df["train_f1_mean"], marker="o", linestyle="-",
         color="RoyalBlue", label="Train F1")
plt.plot(x, mlp_1_cv_df["train_roc_auc_mean"], marker="s", linestyle="--",
         color="RoyalBlue", label="Train ROC-AUC")

# Validation metrics
plt.plot(x, mlp_1_cv_df["val_f1_mean"], marker="o", linestyle="-",
         color="Crimson", label="Val F1")
plt.plot(x, mlp_1_cv_df["val_roc_auc_mean"], marker="s", linestyle="--",
         color="Crimson", label="Val ROC-AUC")

# Highlight best model by val ROC-AUC
best_idx = mlp_1_cv_df["val_roc_auc_mean"].idxmax()
plt.axvspan(
    best_idx - 0.1,
    best_idx + 0.1,
    color="Plum",
    alpha=0.2,
    label="Best Model"
)

# Labels & style
plt.xticks(x, mlp_1_cv_df["label"], rotation=45)
plt.title("MLP 1: Hyperparameter Tuning (CV Mean Metrics)", weight="bold")
plt.ylabel("Score")
plt.grid(True, linestyle="--", linewidth=0.5, alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## MLP 2, &ensp; $h = [64, 32]$
#
# This time, we found our highest validation set ROC-AUC score when our dropout rate was set to
# ${\color{Gray}{0.2}}$
# and our learning rate was set to
# ${\color{HotPink}{\eta}}
#     = {\color{HotPink}{0.0005}}$.
#
# However, results from our coss validation folds still show that the train set ROC-AUC score hovers at around
# $0.96$,
# while the validation was still close to
# $0.56$,
# so our model still suffers from overfitting.

# %%
# =========================
# Tuning MLP 2 on 5-fold CV
# =========================
dropouts = [0.2, 0.3]
learning_rates = [0.001, 0.0005]
k_folds = 5

mlp_2_cv_summary = []

skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=random_state)

for do in dropouts:
    for lr in learning_rates:
        display(HTML(f"<br><strong>Training MLP 2, &ensp; h = [64, 32]"
                     f"&ensp; with dropout={do}, lr={lr}</strong><br>"))        
        
        fold_train_roc_auc = []
        fold_val_roc_auc = []
        fold_train_f1 = []
        fold_val_f1 = []

        for fold, (train_idx, val_idx) in enumerate(skf.split(X_train_enc, y_train)):
            X_tr, X_val = X_train_enc.iloc[train_idx], X_train_enc.iloc[val_idx]
            y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]

            # Build & compile model
            model = build_mlp_2(input_shape=X_train_enc.shape[1], dropout=do)
            model.compile(optimizer=Adam(learning_rate=lr),
                          loss="binary_crossentropy",
                          metrics=[tf.keras.metrics.AUC(name="auc"),
                                   Precision(name="prec"),
                                   Recall(name="rec")])

            early_stop = EarlyStopping(
            monitor="val_roc_auc",
            patience=8,
            mode="max",
            restore_best_weights=True
            )
            
            # Train
            history = model.fit(
                X_tr, y_tr,
                validation_data=(X_val, y_val),
                epochs=80,
                batch_size=64,
                verbose=0,
                class_weight=class_weights_dict,
                callbacks=[early_stop] 
            )

            # Predict
            train_probs = model.predict(X_tr, verbose=0).flatten()
            val_probs = model.predict(X_val, verbose=0).flatten()
            train_preds = (train_probs > 0.5).astype(int)
            val_preds = (val_probs > 0.5).astype(int)

            # Compute metrics
            tr_roc_auc = roc_auc_score(y_tr, train_probs)
            val_roc_auc = roc_auc_score(y_val, val_probs)
            tr_f1 = f1_score(y_tr, train_preds)
            val_f1 = f1_score(y_val, val_preds)
            
            fold_train_roc_auc.append(tr_roc_auc)
            fold_val_roc_auc.append(val_roc_auc)
            fold_train_f1.append(tr_f1)
            fold_val_f1.append(val_f1)

            # Track best ROC-AUC for this fold
            print(f"\nFold {fold+1}:")
            print(f"   Train ROC-AUC: {tr_roc_auc:.4f} | Train F1: {tr_f1:.4f}")
            print(f"   Val   ROC-AUC: {val_roc_auc:.4f} | Val   F1: {val_f1:.4f}")

            # Confusion matrix for this fold
            cm = confusion_matrix(y_val, val_preds)
            print("    Confusion Matrix (Val):")
            print(cm)

        # Save mean metrics across folds
        mlp_2_cv_summary.append({
            "dropout_rate": do,
            "lr": lr,
            "train_roc_auc_mean": np.mean(fold_train_roc_auc),
            "val_roc_auc_mean": np.mean(fold_val_roc_auc),
            "train_f1_mean": np.mean(fold_train_f1),
            "val_f1_mean": np.mean(fold_val_f1),
        })

# Convert to DataFrame
mlp_2_cv_df = pd.DataFrame(mlp_2_cv_summary)

# Highlight best mean val ROC-AUC
def highlight_best_val_roc_auc(row):
    if row["val_roc_auc_mean"] == mlp_2_cv_df["val_roc_auc_mean"].max():
        return ["background-color: #F4DCF3"]*len(row)
    return [""]*len(row)

display(HTML(f"<br><strong>Training MLP 2, &ensp; h = [64, 32]"
                     f"&ensp; HyperParameter Summary</strong><br>"))   
display(mlp_2_cv_df.style.apply(highlight_best_val_roc_auc, axis=1))
# Out:
# <br><strong>Training MLP 2, &ensp; h = [64, 32]&ensp; with dropout=0.2, lr=0.001</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.9868 | Train F1: 0.8998
#    Val   ROC-AUC: 0.5325 | Val   F1: 0.8184
#     Confusion Matrix (Val):
# [[ 30  71]
#  [264 755]]
#
# Fold 2:
#    Train ROC-AUC: 0.9863 | Train F1: 0.9384
#    Val   ROC-AUC: 0.5716 | Val   F1: 0.8600
#     Confusion Matrix (Val):
# [[ 21  80]
#  [190 829]]
#
# Fold 3:
#    Train ROC-AUC: 0.9864 | Train F1: 0.9385
#    Val   ROC-AUC: 0.5319 | Val   F1: 0.8536
#     Confusion Matrix (Val):
# [[ 24  77]
#  [203 816]]
#
# Fold 4:
#    Train ROC-AUC: 0.9842 | Train F1: 0.9218
#    Val   ROC-AUC: 0.5380 | Val   F1: 0.8385
#     Confusion Matrix (Val):
# [[ 23  78]
#  [227 792]]
#
# Fold 5:
#    Train ROC-AUC: 0.9864 | Train F1: 0.9640
#    Val   ROC-AUC: 0.5554 | Val   F1: 0.8746
#     Confusion Matrix (Val):
# [[ 16  86]
#  [160 858]]
# <br><strong>Training MLP 2, &ensp; h = [64, 32]&ensp; with dropout=0.2, lr=0.0005</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.9634 | Train F1: 0.8976
#    Val   ROC-AUC: 0.5740 | Val   F1: 0.8365
#     Confusion Matrix (Val):
# [[ 35  66]
#  [239 780]]
#
# Fold 2:
#    Train ROC-AUC: 0.9631 | Train F1: 0.9218
#    Val   ROC-AUC: 0.4992 | Val   F1: 0.8478
#     Confusion Matrix (Val):
# [[ 22  79]
#  [211 808]]
#
# Fold 3:
#    Train ROC-AUC: 0.9617 | Train F1: 0.8981
#    Val   ROC-AUC: 0.5704 | Val   F1: 0.8405
#     Confusion Matrix (Val):
# [[ 37  64]
#  [234 785]]
#
# Fold 4:
#    Train ROC-AUC: 0.9644 | Train F1: 0.8864
#    Val   ROC-AUC: 0.5348 | Val   F1: 0.8062
#     Confusion Matrix (Val):
# [[ 36  65]
#  [287 732]]
#
# Fold 5:
#    Train ROC-AUC: 0.9619 | Train F1: 0.9080
#    Val   ROC-AUC: 0.5991 | Val   F1: 0.8395
#     Confusion Matrix (Val):
# [[ 32  70]
#  [231 787]]
# <br><strong>Training MLP 2, &ensp; h = [64, 32]&ensp; with dropout=0.3, lr=0.001</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.9677 | Train F1: 0.9052
#    Val   ROC-AUC: 0.6340 | Val   F1: 0.8371
#     Confusion Matrix (Val):
# [[ 42  59]
#  [243 776]]
#
# Fold 2:
#    Train ROC-AUC: 0.9630 | Train F1: 0.8665
#    Val   ROC-AUC: 0.5276 | Val   F1: 0.7920
#     Confusion Matrix (Val):
# [[ 31  70]
#  [305 714]]
#
# Fold 3:
#    Train ROC-AUC: 0.9615 | Train F1: 0.9039
#    Val   ROC-AUC: 0.5390 | Val   F1: 0.8153
#     Confusion Matrix (Val):
# [[ 23  78]
#  [264 755]]
#
# Fold 4:
#    Train ROC-AUC: 0.9641 | Train F1: 0.9001
#    Val   ROC-AUC: 0.5229 | Val   F1: 0.8287
#     Confusion Matrix (Val):
# [[ 26  75]
#  [245 774]]
#
# Fold 5:
#    Train ROC-AUC: 0.9663 | Train F1: 0.8490
#    Val   ROC-AUC: 0.5246 | Val   F1: 0.7600
#     Confusion Matrix (Val):
# [[ 35  67]
#  [353 665]]
# <br><strong>Training MLP 2, &ensp; h = [64, 32]&ensp; with dropout=0.3, lr=0.0005</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.9140 | Train F1: 0.8605
#    Val   ROC-AUC: 0.5848 | Val   F1: 0.8127
#     Confusion Matrix (Val):
# [[ 36  65]
#  [277 742]]
#
# Fold 2:
#    Train ROC-AUC: 0.9156 | Train F1: 0.7962
#    Val   ROC-AUC: 0.5202 | Val   F1: 0.7242
#     Confusion Matrix (Val):
# [[ 40  61]
#  [406 613]]
#
# Fold 3:
#    Train ROC-AUC: 0.9073 | Train F1: 0.8572
#    Val   ROC-AUC: 0.5762 | Val   F1: 0.8031
#     Confusion Matrix (Val):
# [[ 38  63]
#  [293 726]]
#
# Fold 4:
#    Train ROC-AUC: 0.9244 | Train F1: 0.8405
#    Val   ROC-AUC: 0.5241 | Val   F1: 0.7804
#     Confusion Matrix (Val):
# [[ 37  64]
#  [326 693]]
#
# Fold 5:
#    Train ROC-AUC: 0.9128 | Train F1: 0.8968
#    Val   ROC-AUC: 0.5703 | Val   F1: 0.8329
#     Confusion Matrix (Val):
# [[ 34  68]
#  [243 775]]
# <br><strong>Training MLP 2, &ensp; h = [64, 32]&ensp; HyperParameter Summary</strong><br>
# <style type="text/css">
# #T_30e09_row1_col0, #T_30e09_row1_col1, #T_30e09_row1_col2, #T_30e09_row1_col3, #T_30e09_row1_col4, #T_30e09_row1_col5 {
#   background-color: #F4DCF3;
# }
# </style>
# <table id="T_30e09">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30e09_level0_col0" class="col_heading level0 col0" >dropout_rate</th>
#       <th id="T_30e09_level0_col1" class="col_heading level0 col1" >lr</th>
#       <th id="T_30e09_level0_col2" class="col_heading level0 col2" >train_roc_auc_mean</th>
#       <th id="T_30e09_level0_col3" class="col_heading level0 col3" >val_roc_auc_mean</th>
#       <th id="T_30e09_level0_col4" class="col_heading level0 col4" >train_f1_mean</th>
#       <th id="T_30e09_level0_col5" class="col_heading level0 col5" >val_f1_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30e09_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30e09_row0_col0" class="data row0 col0" >0.200000</td>
#       <td id="T_30e09_row0_col1" class="data row0 col1" >0.001000</td>
#       <td id="T_30e09_row0_col2" class="data row0 col2" >0.986014</td>
#       <td id="T_30e09_row0_col3" class="data row0 col3" >0.545884</td>
#       <td id="T_30e09_row0_col4" class="data row0 col4" >0.932532</td>
#       <td id="T_30e09_row0_col5" class="data row0 col5" >0.849020</td>
#     </tr>
#     <tr>
#       <th id="T_30e09_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_30e09_row1_col0" class="data row1 col0" >0.200000</td>
#       <td id="T_30e09_row1_col1" class="data row1 col1" >0.000500</td>
#       <td id="T_30e09_row1_col2" class="data row1 col2" >0.962911</td>
#       <td id="T_30e09_row1_col3" class="data row1 col3" >0.555494</td>
#       <td id="T_30e09_row1_col4" class="data row1 col4" >0.902395</td>
#       <td id="T_30e09_row1_col5" class="data row1 col5" >0.834083</td>
#     </tr>
#     <tr>
#       <th id="T_30e09_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_30e09_row2_col0" class="data row2 col0" >0.300000</td>
#       <td id="T_30e09_row2_col1" class="data row2 col1" >0.001000</td>
#       <td id="T_30e09_row2_col2" class="data row2 col2" >0.964504</td>
#       <td id="T_30e09_row2_col3" class="data row2 col3" >0.549615</td>
#       <td id="T_30e09_row2_col4" class="data row2 col4" >0.884928</td>
#       <td id="T_30e09_row2_col5" class="data row2 col5" >0.806630</td>
#     </tr>
#     <tr>
#       <th id="T_30e09_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_30e09_row3_col0" class="data row3 col0" >0.300000</td>
#       <td id="T_30e09_row3_col1" class="data row3 col1" >0.000500</td>
#       <td id="T_30e09_row3_col2" class="data row3 col2" >0.914808</td>
#       <td id="T_30e09_row3_col3" class="data row3 col3" >0.555103</td>
#       <td id="T_30e09_row3_col4" class="data row3 col4" >0.850249</td>
#       <td id="T_30e09_row3_col5" class="data row3 col5" >0.790650</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ========================
# Plot MLP 2 CV Results
# ========================
mlp_2_cv_df["label"] = mlp_2_cv_df.apply(
    lambda row: f"drop={row['dropout_rate']}, lr={row['lr']}", axis=1
)

x = range(len(mlp_2_cv_df))
plt.figure(figsize=(10,6))

# Train metrics
plt.plot(x, mlp_2_cv_df["train_f1_mean"], marker="o", linestyle="-",
         color="RoyalBlue", label="Train F1")
plt.plot(x, mlp_2_cv_df["train_roc_auc_mean"], marker="s", linestyle="--",
         color="RoyalBlue", label="Train ROC-AUC")

# Validation metrics
plt.plot(x, mlp_2_cv_df["val_f1_mean"], marker="o", linestyle="-",
         color="Crimson", label="Val F1")
plt.plot(x, mlp_2_cv_df["val_roc_auc_mean"], marker="s", linestyle="--",
         color="Crimson", label="Val ROC-AUC")

# Highlight best model by val ROC-AUC
best_idx = mlp_2_cv_df["val_roc_auc_mean"].idxmax()
plt.axvspan(
    best_idx - 0.1,
    best_idx + 0.1,
    color="Plum",
    alpha=0.2,
    label="Best Model"
)

# Labels & style
plt.xticks(x, mlp_2_cv_df["label"], rotation=45)
plt.title("MLP 2: Hyperparameter Tuning (CV Mean Metrics)", weight="bold")
plt.ylabel("Score")
plt.grid(True, linestyle="--", linewidth=0.5, alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## MLP 3, &ensp; $h = [16, 8]$
#
# With this version of our MLP model, we found our highest ROC-AUC score when our dropout rate was set to
# ${\color{Gray}{0.3}}$
# and our learning rate was set to
# ${\color{HotPink}{\eta}}
#     = {\color{HotPink}{0.0005}}$.
#
# Results from our cross-validation folds show we're making some progress at addressing overfitting. The train set ROC-AUC score hovers at around
# $0.78$,
# and the validation shows a slightly improved score of
# $0.59$. This is already more realistic than previous versions.

# %%
# =========================
# Tuning MLP 3 on 5-fold CV
# =========================
dropouts = [0.2, 0.3]
learning_rates = [0.001, 0.0005]
k_folds = 5

mlp_3_cv_summary = []

skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=random_state)

for do in dropouts:
    for lr in learning_rates:
        display(HTML(f"<br><strong>Training MLP 3, &ensp; h = [16, 8]"
                     f"&ensp; with dropout={do}, lr={lr}</strong><br>"))        
        
        fold_train_roc_auc = []
        fold_val_roc_auc = []
        fold_train_f1 = []
        fold_val_f1 = []

        for fold, (train_idx, val_idx) in enumerate(skf.split(X_train_enc, y_train)):
            X_tr, X_val = X_train_enc.iloc[train_idx], X_train_enc.iloc[val_idx]
            y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]

            # Build & compile model
            model = build_mlp_3(input_shape=X_train_enc.shape[1], dropout=do)
            model.compile(optimizer=Adam(learning_rate=lr),
                          loss="binary_crossentropy",
                          metrics=[tf.keras.metrics.AUC(name="auc"),
                                   Precision(name="prec"),
                                   Recall(name="rec")])

            early_stop = EarlyStopping(
            monitor="val_roc_auc",
            patience=8,
            mode="max",
            restore_best_weights=True
            )
            
            # Train
            history = model.fit(
                X_tr, y_tr,
                validation_data=(X_val, y_val),
                epochs=80,
                batch_size=64,
                verbose=0,
                class_weight=class_weights_dict,
                callbacks=[early_stop] 
            )

            # Predict
            train_probs = model.predict(X_tr, verbose=0).flatten()
            val_probs = model.predict(X_val, verbose=0).flatten()
            train_preds = (train_probs > 0.5).astype(int)
            val_preds = (val_probs > 0.5).astype(int)

            # Compute metrics
            tr_roc_auc = roc_auc_score(y_tr, train_probs)
            val_roc_auc = roc_auc_score(y_val, val_probs)
            tr_f1 = f1_score(y_tr, train_preds)
            val_f1 = f1_score(y_val, val_preds)
            
            fold_train_roc_auc.append(tr_roc_auc)
            fold_val_roc_auc.append(val_roc_auc)
            fold_train_f1.append(tr_f1)
            fold_val_f1.append(val_f1)

            # Track best ROC-AUC for this fold
            print(f"\nFold {fold+1}:")
            print(f"   Train ROC-AUC: {tr_roc_auc:.4f} | Train F1: {tr_f1:.4f}")
            print(f"   Val   ROC-AUC: {val_roc_auc:.4f} | Val   F1: {val_f1:.4f}")

            # Confusion matrix for this fold
            cm = confusion_matrix(y_val, val_preds)
            print("    Confusion Matrix (Val):")
            print(cm)

        # Save mean metrics across folds
        mlp_3_cv_summary.append({
            "dropout_rate": do,
            "lr": lr,
            "train_roc_auc_mean": np.mean(fold_train_roc_auc),
            "val_roc_auc_mean": np.mean(fold_val_roc_auc),
            "train_f1_mean": np.mean(fold_train_f1),
            "val_f1_mean": np.mean(fold_val_f1),
        })

# Convert to DataFrame
mlp_3_cv_df = pd.DataFrame(mlp_3_cv_summary)

# Highlight best mean val ROC-AUC
def highlight_best_val_roc_auc(row):
    if row["val_roc_auc_mean"] == mlp_3_cv_df["val_roc_auc_mean"].max():
        return ["background-color: #F4DCF3"]*len(row)
    return [""]*len(row)

display(HTML(f"<br><strong>Training MLP 3, &ensp; h = [16, 8]"
                     f"&ensp; HyperParameter Summary</strong><br>"))   
display(mlp_3_cv_df.style.apply(highlight_best_val_roc_auc, axis=1))
# Out:
# <br><strong>Training MLP 3, &ensp; h = [16, 8]&ensp; with dropout=0.2, lr=0.001</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.8195 | Train F1: 0.8035
#    Val   ROC-AUC: 0.5963 | Val   F1: 0.7702
#     Confusion Matrix (Val):
# [[ 47  54]
#  [347 672]]
#
# Fold 2:
#    Train ROC-AUC: 0.8034 | Train F1: 0.7331
#    Val   ROC-AUC: 0.5918 | Val   F1: 0.6909
#     Confusion Matrix (Val):
# [[ 57  44]
#  [458 561]]
#
# Fold 3:
#    Train ROC-AUC: 0.8160 | Train F1: 0.7970
#    Val   ROC-AUC: 0.5584 | Val   F1: 0.7687
#     Confusion Matrix (Val):
# [[ 42  59]
#  [346 673]]
#
# Fold 4:
#    Train ROC-AUC: 0.8083 | Train F1: 0.8400
#    Val   ROC-AUC: 0.6019 | Val   F1: 0.8062
#     Confusion Matrix (Val):
# [[ 42  59]
#  [291 728]]
#
# Fold 5:
#    Train ROC-AUC: 0.8250 | Train F1: 0.8393
#    Val   ROC-AUC: 0.5793 | Val   F1: 0.7984
#     Confusion Matrix (Val):
# [[ 38  64]
#  [299 719]]
# <br><strong>Training MLP 3, &ensp; h = [16, 8]&ensp; with dropout=0.2, lr=0.0005</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.7719 | Train F1: 0.7341
#    Val   ROC-AUC: 0.5886 | Val   F1: 0.7075
#     Confusion Matrix (Val):
# [[ 53  48]
#  [435 584]]
#
# Fold 2:
#    Train ROC-AUC: 0.7758 | Train F1: 0.7771
#    Val   ROC-AUC: 0.5678 | Val   F1: 0.7382
#     Confusion Matrix (Val):
# [[ 50  51]
#  [393 626]]
#
# Fold 3:
#    Train ROC-AUC: 0.7597 | Train F1: 0.7326
#    Val   ROC-AUC: 0.5804 | Val   F1: 0.7180
#     Confusion Matrix (Val):
# [[ 54  47]
#  [422 597]]
#
# Fold 4:
#    Train ROC-AUC: 0.7683 | Train F1: 0.7825
#    Val   ROC-AUC: 0.6053 | Val   F1: 0.7507
#     Confusion Matrix (Val):
# [[ 55  46]
#  [379 640]]
#
# Fold 5:
#    Train ROC-AUC: 0.7586 | Train F1: 0.7713
#    Val   ROC-AUC: 0.6189 | Val   F1: 0.7445
#     Confusion Matrix (Val):
# [[ 56  46]
#  [387 631]]
# <br><strong>Training MLP 3, &ensp; h = [16, 8]&ensp; with dropout=0.3, lr=0.001</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.7892 | Train F1: 0.7700
#    Val   ROC-AUC: 0.5776 | Val   F1: 0.7282
#     Confusion Matrix (Val):
# [[ 46  55]
#  [404 615]]
#
# Fold 2:
#    Train ROC-AUC: 0.7839 | Train F1: 0.7266
#    Val   ROC-AUC: 0.6080 | Val   F1: 0.7035
#     Confusion Matrix (Val):
# [[ 64  37]
#  [446 573]]
#
# Fold 3:
#    Train ROC-AUC: 0.7705 | Train F1: 0.7498
#    Val   ROC-AUC: 0.6193 | Val   F1: 0.7281
#     Confusion Matrix (Val):
# [[ 58  43]
#  [411 608]]
#
# Fold 4:
#    Train ROC-AUC: 0.7492 | Train F1: 0.7533
#    Val   ROC-AUC: 0.5843 | Val   F1: 0.7288
#     Confusion Matrix (Val):
# [[ 56  45]
#  [409 610]]
#
# Fold 5:
#    Train ROC-AUC: 0.7654 | Train F1: 0.7233
#    Val   ROC-AUC: 0.6218 | Val   F1: 0.6890
#     Confusion Matrix (Val):
# [[ 64  38]
#  [463 555]]
# <br><strong>Training MLP 3, &ensp; h = [16, 8]&ensp; with dropout=0.3, lr=0.0005</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.7256 | Train F1: 0.6731
#    Val   ROC-AUC: 0.5916 | Val   F1: 0.6260
#     Confusion Matrix (Val):
# [[ 62  39]
#  [537 482]]
#
# Fold 2:
#    Train ROC-AUC: 0.7218 | Train F1: 0.7632
#    Val   ROC-AUC: 0.6016 | Val   F1: 0.7537
#     Confusion Matrix (Val):
# [[ 55  46]
#  [375 644]]
#
# Fold 3:
#    Train ROC-AUC: 0.7430 | Train F1: 0.7097
#    Val   ROC-AUC: 0.6229 | Val   F1: 0.6942
#     Confusion Matrix (Val):
# [[ 59  42]
#  [455 564]]
#
# Fold 4:
#    Train ROC-AUC: 0.7272 | Train F1: 0.7841
#    Val   ROC-AUC: 0.6193 | Val   F1: 0.7725
#     Confusion Matrix (Val):
# [[ 49  52]
#  [345 674]]
#
# Fold 5:
#    Train ROC-AUC: 0.7393 | Train F1: 0.7267
#    Val   ROC-AUC: 0.6013 | Val   F1: 0.7037
#     Confusion Matrix (Val):
# [[ 57  45]
#  [441 577]]
# <br><strong>Training MLP 3, &ensp; h = [16, 8]&ensp; HyperParameter Summary</strong><br>
# <style type="text/css">
# #T_0add5_row3_col0, #T_0add5_row3_col1, #T_0add5_row3_col2, #T_0add5_row3_col3, #T_0add5_row3_col4, #T_0add5_row3_col5 {
#   background-color: #F4DCF3;
# }
# </style>
# <table id="T_0add5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0add5_level0_col0" class="col_heading level0 col0" >dropout_rate</th>
#       <th id="T_0add5_level0_col1" class="col_heading level0 col1" >lr</th>
#       <th id="T_0add5_level0_col2" class="col_heading level0 col2" >train_roc_auc_mean</th>
#       <th id="T_0add5_level0_col3" class="col_heading level0 col3" >val_roc_auc_mean</th>
#       <th id="T_0add5_level0_col4" class="col_heading level0 col4" >train_f1_mean</th>
#       <th id="T_0add5_level0_col5" class="col_heading level0 col5" >val_f1_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0add5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0add5_row0_col0" class="data row0 col0" >0.200000</td>
#       <td id="T_0add5_row0_col1" class="data row0 col1" >0.001000</td>
#       <td id="T_0add5_row0_col2" class="data row0 col2" >0.814446</td>
#       <td id="T_0add5_row0_col3" class="data row0 col3" >0.585557</td>
#       <td id="T_0add5_row0_col4" class="data row0 col4" >0.802568</td>
#       <td id="T_0add5_row0_col5" class="data row0 col5" >0.766888</td>
#     </tr>
#     <tr>
#       <th id="T_0add5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0add5_row1_col0" class="data row1 col0" >0.200000</td>
#       <td id="T_0add5_row1_col1" class="data row1 col1" >0.000500</td>
#       <td id="T_0add5_row1_col2" class="data row1 col2" >0.766828</td>
#       <td id="T_0add5_row1_col3" class="data row1 col3" >0.592202</td>
#       <td id="T_0add5_row1_col4" class="data row1 col4" >0.759510</td>
#       <td id="T_0add5_row1_col5" class="data row1 col5" >0.731783</td>
#     </tr>
#     <tr>
#       <th id="T_0add5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0add5_row2_col0" class="data row2 col0" >0.300000</td>
#       <td id="T_0add5_row2_col1" class="data row2 col1" >0.001000</td>
#       <td id="T_0add5_row2_col2" class="data row2 col2" >0.771648</td>
#       <td id="T_0add5_row2_col3" class="data row2 col3" >0.602200</td>
#       <td id="T_0add5_row2_col4" class="data row2 col4" >0.744592</td>
#       <td id="T_0add5_row2_col5" class="data row2 col5" >0.715538</td>
#     </tr>
#     <tr>
#       <th id="T_0add5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0add5_row3_col0" class="data row3 col0" >0.300000</td>
#       <td id="T_0add5_row3_col1" class="data row3 col1" >0.000500</td>
#       <td id="T_0add5_row3_col2" class="data row3 col2" >0.731373</td>
#       <td id="T_0add5_row3_col3" class="data row3 col3" >0.607316</td>
#       <td id="T_0add5_row3_col4" class="data row3 col4" >0.731348</td>
#       <td id="T_0add5_row3_col5" class="data row3 col5" >0.709987</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ========================
# Plot MLP 3 CV Results
# ========================
mlp_3_cv_df["label"] = mlp_3_cv_df.apply(
    lambda row: f"drop={row['dropout_rate']}, lr={row['lr']}", axis=1
)

x = range(len(mlp_3_cv_df))
plt.figure(figsize=(10,6))

# Train metrics
plt.plot(x, mlp_3_cv_df["train_f1_mean"], marker="o", linestyle="-",
         color="RoyalBlue", label="Train F1")
plt.plot(x, mlp_3_cv_df["train_roc_auc_mean"], marker="s", linestyle="--",
         color="RoyalBlue", label="Train ROC-AUC")

# Validation metrics
plt.plot(x, mlp_3_cv_df["val_f1_mean"], marker="o", linestyle="-",
         color="Crimson", label="Val F1")
plt.plot(x, mlp_3_cv_df["val_roc_auc_mean"], marker="s", linestyle="--",
         color="Crimson", label="Val ROC-AUC")

# Highlight best model by val ROC-AUC
best_idx = mlp_3_cv_df["val_roc_auc_mean"].idxmax()
plt.axvspan(
    best_idx - 0.1,
    best_idx + 0.1,
    color="Plum",
    alpha=0.2,
    label="Best Model"
)

# Labels & style
plt.xticks(x, mlp_3_cv_df["label"], rotation=45)
plt.title("MLP 3: Hyperparameter Tuning (CV Mean Metrics)", weight="bold")
plt.ylabel("Score")
plt.grid(True, linestyle="--", linewidth=0.5, alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ---
# ## MLP 4, &ensp; $h = [4, 2]$
#
# For the fourth version of our model, we found our highest ROC-AUC score when our dropout rate was set to
# ${\color{Gray}{0.3}}$
# and our learning rate was set to
# ${\color{HotPink}{\eta}}
#     = {\color{HotPink}{0.0005}}$.
#
# Results from our cross-validation folds show that our train set ROC-AUC is at around
# $0.66$,
# and the validation set is around
# $0.58$.
# This is similar to what we found in the previous version.

# %%
# =========================
# Tuning MLP 4 on 5-fold CV
# =========================
dropouts = [0.2, 0.3]
learning_rates = [0.001, 0.0005]
k_folds = 5

mlp_4_cv_summary = []

skf = StratifiedKFold(n_splits=k_folds, shuffle=True, random_state=random_state)

for do in dropouts:
    for lr in learning_rates:
        display(HTML(f"<br><strong>Training MLP 4, &ensp; h = [4, 2]"
                     f"&ensp; with dropout={do}, lr={lr}</strong><br>"))        
        
        fold_train_roc_auc = []
        fold_val_roc_auc = []
        fold_train_f1 = []
        fold_val_f1 = []

        for fold, (train_idx, val_idx) in enumerate(skf.split(X_train_enc, y_train)):
            X_tr, X_val = X_train_enc.iloc[train_idx], X_train_enc.iloc[val_idx]
            y_tr, y_val = y_train.iloc[train_idx], y_train.iloc[val_idx]

            # Build & compile model
            model = build_mlp_4(input_shape=X_train_enc.shape[1], dropout=do)
            model.compile(optimizer=Adam(learning_rate=lr),
                          loss="binary_crossentropy",
                          metrics=[tf.keras.metrics.AUC(name="auc"),
                                   Precision(name="prec"),
                                   Recall(name="rec")])

            early_stop = EarlyStopping(
            monitor="val_roc_auc",
            patience=8,
            mode="max",
            restore_best_weights=True
            )
            
            # Train
            history = model.fit(
                X_tr, y_tr,
                validation_data=(X_val, y_val),
                epochs=80,
                batch_size=64,
                verbose=0,
                class_weight=class_weights_dict,
                callbacks=[early_stop] 
            )

            # Predict
            train_probs = model.predict(X_tr, verbose=0).flatten()
            val_probs = model.predict(X_val, verbose=0).flatten()
            train_preds = (train_probs > 0.5).astype(int)
            val_preds = (val_probs > 0.5).astype(int)

            # Compute metrics
            tr_roc_auc = roc_auc_score(y_tr, train_probs)
            val_roc_auc = roc_auc_score(y_val, val_probs)
            tr_f1 = f1_score(y_tr, train_preds)
            val_f1 = f1_score(y_val, val_preds)
            
            fold_train_roc_auc.append(tr_roc_auc)
            fold_val_roc_auc.append(val_roc_auc)
            fold_train_f1.append(tr_f1)
            fold_val_f1.append(val_f1)

            # Track best ROC-AUC for this fold
            print(f"\nFold {fold+1}:")
            print(f"   Train ROC-AUC: {tr_roc_auc:.4f} | Train F1: {tr_f1:.4f}")
            print(f"   Val   ROC-AUC: {val_roc_auc:.4f} | Val   F1: {val_f1:.4f}")

            # Confusion matrix for this fold
            cm = confusion_matrix(y_val, val_preds)
            print("    Confusion Matrix (Val):")
            print(cm)

        # Save mean metrics across folds
        mlp_4_cv_summary.append({
            "dropout_rate": do,
            "lr": lr,
            "train_roc_auc_mean": np.mean(fold_train_roc_auc),
            "val_roc_auc_mean": np.mean(fold_val_roc_auc),
            "train_f1_mean": np.mean(fold_train_f1),
            "val_f1_mean": np.mean(fold_val_f1),
        })

# Convert to DataFrame
mlp_4_cv_df = pd.DataFrame(mlp_4_cv_summary)

# Highlight best mean val ROC-AUC
def highlight_best_val_roc_auc(row):
    if row["val_roc_auc_mean"] == mlp_4_cv_df["val_roc_auc_mean"].max():
        return ["background-color: #F4DCF3"]*len(row)
    return [""]*len(row)


display(HTML(f"<br><strong>Training MLP 4, &ensp; h = [4, 2]"
                     f"&ensp; HyperParameter Summary</strong><br>"))    
display(mlp_4_cv_df.style.apply(highlight_best_val_roc_auc, axis=1))
# Out:
# <br><strong>Training MLP 4, &ensp; h = [4, 2]&ensp; with dropout=0.2, lr=0.001</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.6984 | Train F1: 0.7888
#    Val   ROC-AUC: 0.5711 | Val   F1: 0.7683
#     Confusion Matrix (Val):
# [[ 49  52]
#  [351 668]]
#
# Fold 2:
#    Train ROC-AUC: 0.6761 | Train F1: 0.6857
#    Val   ROC-AUC: 0.6016 | Val   F1: 0.6608
#     Confusion Matrix (Val):
# [[ 62  39]
#  [497 522]]
#
# Fold 3:
#    Train ROC-AUC: 0.6890 | Train F1: 0.6683
#    Val   ROC-AUC: 0.6084 | Val   F1: 0.6586
#     Confusion Matrix (Val):
# [[ 67  34]
#  [502 517]]
#
# Fold 4:
#    Train ROC-AUC: 0.6951 | Train F1: 0.7028
#    Val   ROC-AUC: 0.5911 | Val   F1: 0.6877
#     Confusion Matrix (Val):
# [[ 59  42]
#  [463 556]]
#
# Fold 5:
#    Train ROC-AUC: 0.6418 | Train F1: 0.5664
#    Val   ROC-AUC: 0.5889 | Val   F1: 0.5718
#     Confusion Matrix (Val):
# [[ 76  26]
#  [600 418]]
# <br><strong>Training MLP 4, &ensp; h = [4, 2]&ensp; with dropout=0.2, lr=0.0005</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.6484 | Train F1: 0.5786
#    Val   ROC-AUC: 0.5672 | Val   F1: 0.5542
#     Confusion Matrix (Val):
# [[ 66  35]
#  [615 404]]
#
# Fold 2:
#    Train ROC-AUC: 0.6364 | Train F1: 0.8665
#    Val   ROC-AUC: 0.5671 | Val   F1: 0.8543
#     Confusion Matrix (Val):
# [[ 27  74]
#  [204 815]]
#
# Fold 3:
#    Train ROC-AUC: 0.5707 | Train F1: 0.8572
#    Val   ROC-AUC: 0.5235 | Val   F1: 0.8472
#     Confusion Matrix (Val):
# [[ 26  75]
#  [215 804]]
#
# Fold 4:
#    Train ROC-AUC: 0.6919 | Train F1: 0.6516
#    Val   ROC-AUC: 0.5800 | Val   F1: 0.6286
#     Confusion Matrix (Val):
# [[ 62  39]
#  [534 485]]
#
# Fold 5:
#    Train ROC-AUC: 0.6801 | Train F1: 0.7371
#    Val   ROC-AUC: 0.5981 | Val   F1: 0.7080
#     Confusion Matrix (Val):
# [[ 58  44]
#  [436 582]]
# <br><strong>Training MLP 4, &ensp; h = [4, 2]&ensp; with dropout=0.3, lr=0.001</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.6770 | Train F1: 0.6428
#    Val   ROC-AUC: 0.5724 | Val   F1: 0.6206
#     Confusion Matrix (Val):
# [[ 62  39]
#  [543 476]]
#
# Fold 2:
#    Train ROC-AUC: 0.6927 | Train F1: 0.6556
#    Val   ROC-AUC: 0.6218 | Val   F1: 0.6508
#     Confusion Matrix (Val):
# [[ 69  32]
#  [512 507]]
#
# Fold 3:
#    Train ROC-AUC: 0.6826 | Train F1: 0.6634
#    Val   ROC-AUC: 0.6053 | Val   F1: 0.6391
#     Confusion Matrix (Val):
# [[ 68  33]
#  [525 494]]
#
# Fold 4:
#    Train ROC-AUC: 0.6912 | Train F1: 0.8233
#    Val   ROC-AUC: 0.5579 | Val   F1: 0.8053
#     Confusion Matrix (Val):
# [[ 37  64]
#  [289 730]]
#
# Fold 5:
#    Train ROC-AUC: 0.6919 | Train F1: 0.7405
#    Val   ROC-AUC: 0.5848 | Val   F1: 0.7167
#     Confusion Matrix (Val):
# [[ 60  42]
#  [426 592]]
# <br><strong>Training MLP 4, &ensp; h = [4, 2]&ensp; with dropout=0.3, lr=0.0005</strong><br>
# Fold 1:
#    Train ROC-AUC: 0.6726 | Train F1: 0.6986
#    Val   ROC-AUC: 0.5862 | Val   F1: 0.6808
#     Confusion Matrix (Val):
# [[ 60  41]
#  [472 547]]
#
# Fold 2:
#    Train ROC-AUC: 0.6551 | Train F1: 0.6714
#    Val   ROC-AUC: 0.5918 | Val   F1: 0.6633
#     Confusion Matrix (Val):
# [[ 66  35]
#  [496 523]]
#
# Fold 3:
#    Train ROC-AUC: 0.6334 | Train F1: 0.8055
#    Val   ROC-AUC: 0.5921 | Val   F1: 0.7894
#     Confusion Matrix (Val):
# [[ 42  59]
#  [316 703]]
#
# Fold 4:
#    Train ROC-AUC: 0.6696 | Train F1: 0.6321
#    Val   ROC-AUC: 0.6052 | Val   F1: 0.6107
#     Confusion Matrix (Val):
# [[ 69  32]
#  [557 462]]
#
# Fold 5:
#    Train ROC-AUC: 0.6795 | Train F1: 0.6928
#    Val   ROC-AUC: 0.5999 | Val   F1: 0.6763
#     Confusion Matrix (Val):
# [[ 63  39]
#  [478 540]]
# <br><strong>Training MLP 4, &ensp; h = [4, 2]&ensp; HyperParameter Summary</strong><br>
# <style type="text/css">
# #T_3fe43_row3_col0, #T_3fe43_row3_col1, #T_3fe43_row3_col2, #T_3fe43_row3_col3, #T_3fe43_row3_col4, #T_3fe43_row3_col5 {
#   background-color: #F4DCF3;
# }
# </style>
# <table id="T_3fe43">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3fe43_level0_col0" class="col_heading level0 col0" >dropout_rate</th>
#       <th id="T_3fe43_level0_col1" class="col_heading level0 col1" >lr</th>
#       <th id="T_3fe43_level0_col2" class="col_heading level0 col2" >train_roc_auc_mean</th>
#       <th id="T_3fe43_level0_col3" class="col_heading level0 col3" >val_roc_auc_mean</th>
#       <th id="T_3fe43_level0_col4" class="col_heading level0 col4" >train_f1_mean</th>
#       <th id="T_3fe43_level0_col5" class="col_heading level0 col5" >val_f1_mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3fe43_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3fe43_row0_col0" class="data row0 col0" >0.200000</td>
#       <td id="T_3fe43_row0_col1" class="data row0 col1" >0.001000</td>
#       <td id="T_3fe43_row0_col2" class="data row0 col2" >0.680104</td>
#       <td id="T_3fe43_row0_col3" class="data row0 col3" >0.592213</td>
#       <td id="T_3fe43_row0_col4" class="data row0 col4" >0.682397</td>
#       <td id="T_3fe43_row0_col5" class="data row0 col5" >0.669426</td>
#     </tr>
#     <tr>
#       <th id="T_3fe43_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3fe43_row1_col0" class="data row1 col0" >0.200000</td>
#       <td id="T_3fe43_row1_col1" class="data row1 col1" >0.000500</td>
#       <td id="T_3fe43_row1_col2" class="data row1 col2" >0.645517</td>
#       <td id="T_3fe43_row1_col3" class="data row1 col3" >0.567158</td>
#       <td id="T_3fe43_row1_col4" class="data row1 col4" >0.738201</td>
#       <td id="T_3fe43_row1_col5" class="data row1 col5" >0.718473</td>
#     </tr>
#     <tr>
#       <th id="T_3fe43_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3fe43_row2_col0" class="data row2 col0" >0.300000</td>
#       <td id="T_3fe43_row2_col1" class="data row2 col1" >0.001000</td>
#       <td id="T_3fe43_row2_col2" class="data row2 col2" >0.687082</td>
#       <td id="T_3fe43_row2_col3" class="data row2 col3" >0.588438</td>
#       <td id="T_3fe43_row2_col4" class="data row2 col4" >0.705098</td>
#       <td id="T_3fe43_row2_col5" class="data row2 col5" >0.686501</td>
#     </tr>
#     <tr>
#       <th id="T_3fe43_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3fe43_row3_col0" class="data row3 col0" >0.300000</td>
#       <td id="T_3fe43_row3_col1" class="data row3 col1" >0.000500</td>
#       <td id="T_3fe43_row3_col2" class="data row3 col2" >0.662054</td>
#       <td id="T_3fe43_row3_col3" class="data row3 col3" >0.595026</td>
#       <td id="T_3fe43_row3_col4" class="data row3 col4" >0.700073</td>
#       <td id="T_3fe43_row3_col5" class="data row3 col5" >0.684095</td>
#     </tr>
#   </tbody>
# </table>

# %%
# ========================
# Plot MLP 4 CV Results
# ========================
mlp_4_cv_df["label"] = mlp_4_cv_df.apply(
    lambda row: f"drop={row['dropout_rate']}, lr={row['lr']}", axis=1
)

x = range(len(mlp_4_cv_df))
plt.figure(figsize=(10,6))

# Train metrics
plt.plot(x, mlp_4_cv_df["train_f1_mean"], marker="o", linestyle="-",
         color="RoyalBlue", label="Train F1")
plt.plot(x, mlp_4_cv_df["train_roc_auc_mean"], marker="s", linestyle="--",
         color="RoyalBlue", label="Train ROC-AUC")

# Validation metrics
plt.plot(x, mlp_4_cv_df["val_f1_mean"], marker="o", linestyle="-",
         color="Crimson", label="Val F1")
plt.plot(x, mlp_4_cv_df["val_roc_auc_mean"], marker="s", linestyle="--",
         color="Crimson", label="Val ROC-AUC")

# Highlight best model by val ROC-AUC
best_idx = mlp_4_cv_df["val_roc_auc_mean"].idxmax()
plt.axvspan(
    best_idx - 0.1,
    best_idx + 0.1,
    color="Plum",
    alpha=0.2,
    label="Best Model"
)

# Labels & style
plt.xticks(x, mlp_4_cv_df["label"], rotation=45)
plt.title("MLP 4: Hyperparameter Tuning (CV Mean Metrics)", weight="bold")
plt.ylabel("Score")
plt.grid(True, linestyle="--", linewidth=0.5, alpha=0.7)
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# <br>
#
# ---
# ---
# # **5.  Conclusion**
#
# ---
# ## Final Results
#
# The final ROC-AUC scores and F1 scores for all our models are shown in the tables below. The row with the highest validation set ROC-AUC score for each model is marked in Plum.

# %%
def highlight_best_val_roc_auc(df):
    def _highlight(row):
        if row["val_roc_auc_mean"] == df["val_roc_auc_mean"].max():
            return ["background-color: #F4DCF3"] * len(row)
        return [""] * len(row)
    return _highlight

# MLP 1, h = [256, 128]
display(HTML(f"<br><strong>Training MLP 1, &ensp; h = [256, 128]</strong>"))
display(mlp_1_cv_df.style.apply(highlight_best_val_roc_auc(mlp_1_cv_df), axis=1))

# MLP 2, h = [64, 32]
display(HTML(f"<br><strong>Training MLP 2, &ensp; h = [64, 32]</strong>"))
display(mlp_2_cv_df.style.apply(highlight_best_val_roc_auc(mlp_2_cv_df), axis=1))

# MLP 3, h = [16, 8]
display(HTML(f"<br><strong>Training MLP 3, &ensp; h = [16, 8]</strong>"))
display(mlp_3_cv_df.style.apply(highlight_best_val_roc_auc(mlp_3_cv_df), axis=1))

# MLP 4, h = [4, 2]
display(HTML(f"<br><strong>Training MLP 4, &ensp; h = [4, 2]</strong>"))
display(mlp_4_cv_df.style.apply(highlight_best_val_roc_auc(mlp_4_cv_df), axis=1))
# Out:
# <br><strong>Training MLP 1, &ensp; h = [256, 128]</strong>
# <style type="text/css">
# #T_a28e0_row1_col0, #T_a28e0_row1_col1, #T_a28e0_row1_col2, #T_a28e0_row1_col3, #T_a28e0_row1_col4, #T_a28e0_row1_col5, #T_a28e0_row1_col6 {
#   background-color: #F4DCF3;
# }
# </style>
# <table id="T_a28e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a28e0_level0_col0" class="col_heading level0 col0" >dropout_rate</th>
#       <th id="T_a28e0_level0_col1" class="col_heading level0 col1" >lr</th>
#       <th id="T_a28e0_level0_col2" class="col_heading level0 col2" >train_roc_auc_mean</th>
#       <th id="T_a28e0_level0_col3" class="col_heading level0 col3" >val_roc_auc_mean</th>
#       <th id="T_a28e0_level0_col4" class="col_heading level0 col4" >train_f1_mean</th>
#       <th id="T_a28e0_level0_col5" class="col_heading level0 col5" >val_f1_mean</th>
#       <th id="T_a28e0_level0_col6" class="col_heading level0 col6" >label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a28e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a28e0_row0_col0" class="data row0 col0" >0.200000</td>
#       <td id="T_a28e0_row0_col1" class="data row0 col1" >0.001000</td>
#       <td id="T_a28e0_row0_col2" class="data row0 col2" >0.999814</td>
#       <td id="T_a28e0_row0_col3" class="data row0 col3" >0.509323</td>
#       <td id="T_a28e0_row0_col4" class="data row0 col4" >0.994393</td>
#       <td id="T_a28e0_row0_col5" class="data row0 col5" >0.909589</td>
#       <td id="T_a28e0_row0_col6" class="data row0 col6" >drop=0.2, lr=0.001</td>
#     </tr>
#     <tr>
#       <th id="T_a28e0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a28e0_row1_col0" class="data row1 col0" >0.200000</td>
#       <td id="T_a28e0_row1_col1" class="data row1 col1" >0.000500</td>
#       <td id="T_a28e0_row1_col2" class="data row1 col2" >0.999967</td>
#       <td id="T_a28e0_row1_col3" class="data row1 col3" >0.538070</td>
#       <td id="T_a28e0_row1_col4" class="data row1 col4" >0.994720</td>
#       <td id="T_a28e0_row1_col5" class="data row1 col5" >0.908551</td>
#       <td id="T_a28e0_row1_col6" class="data row1 col6" >drop=0.2, lr=0.0005</td>
#     </tr>
#     <tr>
#       <th id="T_a28e0_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_a28e0_row2_col0" class="data row2 col0" >0.300000</td>
#       <td id="T_a28e0_row2_col1" class="data row2 col1" >0.001000</td>
#       <td id="T_a28e0_row2_col2" class="data row2 col2" >0.999728</td>
#       <td id="T_a28e0_row2_col3" class="data row2 col3" >0.528207</td>
#       <td id="T_a28e0_row2_col4" class="data row2 col4" >0.990886</td>
#       <td id="T_a28e0_row2_col5" class="data row2 col5" >0.903249</td>
#       <td id="T_a28e0_row2_col6" class="data row2 col6" >drop=0.3, lr=0.001</td>
#     </tr>
#     <tr>
#       <th id="T_a28e0_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_a28e0_row3_col0" class="data row3 col0" >0.300000</td>
#       <td id="T_a28e0_row3_col1" class="data row3 col1" >0.000500</td>
#       <td id="T_a28e0_row3_col2" class="data row3 col2" >0.999515</td>
#       <td id="T_a28e0_row3_col3" class="data row3 col3" >0.535932</td>
#       <td id="T_a28e0_row3_col4" class="data row3 col4" >0.986643</td>
#       <td id="T_a28e0_row3_col5" class="data row3 col5" >0.903583</td>
#       <td id="T_a28e0_row3_col6" class="data row3 col6" >drop=0.3, lr=0.0005</td>
#     </tr>
#   </tbody>
# </table>
# <br><strong>Training MLP 2, &ensp; h = [64, 32]</strong>
# <style type="text/css">
# #T_26a20_row1_col0, #T_26a20_row1_col1, #T_26a20_row1_col2, #T_26a20_row1_col3, #T_26a20_row1_col4, #T_26a20_row1_col5, #T_26a20_row1_col6 {
#   background-color: #F4DCF3;
# }
# </style>
# <table id="T_26a20">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_26a20_level0_col0" class="col_heading level0 col0" >dropout_rate</th>
#       <th id="T_26a20_level0_col1" class="col_heading level0 col1" >lr</th>
#       <th id="T_26a20_level0_col2" class="col_heading level0 col2" >train_roc_auc_mean</th>
#       <th id="T_26a20_level0_col3" class="col_heading level0 col3" >val_roc_auc_mean</th>
#       <th id="T_26a20_level0_col4" class="col_heading level0 col4" >train_f1_mean</th>
#       <th id="T_26a20_level0_col5" class="col_heading level0 col5" >val_f1_mean</th>
#       <th id="T_26a20_level0_col6" class="col_heading level0 col6" >label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26a20_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26a20_row0_col0" class="data row0 col0" >0.200000</td>
#       <td id="T_26a20_row0_col1" class="data row0 col1" >0.001000</td>
#       <td id="T_26a20_row0_col2" class="data row0 col2" >0.986014</td>
#       <td id="T_26a20_row0_col3" class="data row0 col3" >0.545884</td>
#       <td id="T_26a20_row0_col4" class="data row0 col4" >0.932532</td>
#       <td id="T_26a20_row0_col5" class="data row0 col5" >0.849020</td>
#       <td id="T_26a20_row0_col6" class="data row0 col6" >drop=0.2, lr=0.001</td>
#     </tr>
#     <tr>
#       <th id="T_26a20_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_26a20_row1_col0" class="data row1 col0" >0.200000</td>
#       <td id="T_26a20_row1_col1" class="data row1 col1" >0.000500</td>
#       <td id="T_26a20_row1_col2" class="data row1 col2" >0.962911</td>
#       <td id="T_26a20_row1_col3" class="data row1 col3" >0.555494</td>
#       <td id="T_26a20_row1_col4" class="data row1 col4" >0.902395</td>
#       <td id="T_26a20_row1_col5" class="data row1 col5" >0.834083</td>
#       <td id="T_26a20_row1_col6" class="data row1 col6" >drop=0.2, lr=0.0005</td>
#     </tr>
#     <tr>
#       <th id="T_26a20_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_26a20_row2_col0" class="data row2 col0" >0.300000</td>
#       <td id="T_26a20_row2_col1" class="data row2 col1" >0.001000</td>
#       <td id="T_26a20_row2_col2" class="data row2 col2" >0.964504</td>
#       <td id="T_26a20_row2_col3" class="data row2 col3" >0.549615</td>
#       <td id="T_26a20_row2_col4" class="data row2 col4" >0.884928</td>
#       <td id="T_26a20_row2_col5" class="data row2 col5" >0.806630</td>
#       <td id="T_26a20_row2_col6" class="data row2 col6" >drop=0.3, lr=0.001</td>
#     </tr>
#     <tr>
#       <th id="T_26a20_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_26a20_row3_col0" class="data row3 col0" >0.300000</td>
#       <td id="T_26a20_row3_col1" class="data row3 col1" >0.000500</td>
#       <td id="T_26a20_row3_col2" class="data row3 col2" >0.914808</td>
#       <td id="T_26a20_row3_col3" class="data row3 col3" >0.555103</td>
#       <td id="T_26a20_row3_col4" class="data row3 col4" >0.850249</td>
#       <td id="T_26a20_row3_col5" class="data row3 col5" >0.790650</td>
#       <td id="T_26a20_row3_col6" class="data row3 col6" >drop=0.3, lr=0.0005</td>
#     </tr>
#   </tbody>
# </table>
# <br><strong>Training MLP 3, &ensp; h = [16, 8]</strong>
# <style type="text/css">
# #T_e074d_row3_col0, #T_e074d_row3_col1, #T_e074d_row3_col2, #T_e074d_row3_col3, #T_e074d_row3_col4, #T_e074d_row3_col5, #T_e074d_row3_col6 {
#   background-color: #F4DCF3;
# }
# </style>
# <table id="T_e074d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e074d_level0_col0" class="col_heading level0 col0" >dropout_rate</th>
#       <th id="T_e074d_level0_col1" class="col_heading level0 col1" >lr</th>
#       <th id="T_e074d_level0_col2" class="col_heading level0 col2" >train_roc_auc_mean</th>
#       <th id="T_e074d_level0_col3" class="col_heading level0 col3" >val_roc_auc_mean</th>
#       <th id="T_e074d_level0_col4" class="col_heading level0 col4" >train_f1_mean</th>
#       <th id="T_e074d_level0_col5" class="col_heading level0 col5" >val_f1_mean</th>
#       <th id="T_e074d_level0_col6" class="col_heading level0 col6" >label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e074d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e074d_row0_col0" class="data row0 col0" >0.200000</td>
#       <td id="T_e074d_row0_col1" class="data row0 col1" >0.001000</td>
#       <td id="T_e074d_row0_col2" class="data row0 col2" >0.814446</td>
#       <td id="T_e074d_row0_col3" class="data row0 col3" >0.585557</td>
#       <td id="T_e074d_row0_col4" class="data row0 col4" >0.802568</td>
#       <td id="T_e074d_row0_col5" class="data row0 col5" >0.766888</td>
#       <td id="T_e074d_row0_col6" class="data row0 col6" >drop=0.2, lr=0.001</td>
#     </tr>
#     <tr>
#       <th id="T_e074d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e074d_row1_col0" class="data row1 col0" >0.200000</td>
#       <td id="T_e074d_row1_col1" class="data row1 col1" >0.000500</td>
#       <td id="T_e074d_row1_col2" class="data row1 col2" >0.766828</td>
#       <td id="T_e074d_row1_col3" class="data row1 col3" >0.592202</td>
#       <td id="T_e074d_row1_col4" class="data row1 col4" >0.759510</td>
#       <td id="T_e074d_row1_col5" class="data row1 col5" >0.731783</td>
#       <td id="T_e074d_row1_col6" class="data row1 col6" >drop=0.2, lr=0.0005</td>
#     </tr>
#     <tr>
#       <th id="T_e074d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_e074d_row2_col0" class="data row2 col0" >0.300000</td>
#       <td id="T_e074d_row2_col1" class="data row2 col1" >0.001000</td>
#       <td id="T_e074d_row2_col2" class="data row2 col2" >0.771648</td>
#       <td id="T_e074d_row2_col3" class="data row2 col3" >0.602200</td>
#       <td id="T_e074d_row2_col4" class="data row2 col4" >0.744592</td>
#       <td id="T_e074d_row2_col5" class="data row2 col5" >0.715538</td>
#       <td id="T_e074d_row2_col6" class="data row2 col6" >drop=0.3, lr=0.001</td>
#     </tr>
#     <tr>
#       <th id="T_e074d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_e074d_row3_col0" class="data row3 col0" >0.300000</td>
#       <td id="T_e074d_row3_col1" class="data row3 col1" >0.000500</td>
#       <td id="T_e074d_row3_col2" class="data row3 col2" >0.731373</td>
#       <td id="T_e074d_row3_col3" class="data row3 col3" >0.607316</td>
#       <td id="T_e074d_row3_col4" class="data row3 col4" >0.731348</td>
#       <td id="T_e074d_row3_col5" class="data row3 col5" >0.709987</td>
#       <td id="T_e074d_row3_col6" class="data row3 col6" >drop=0.3, lr=0.0005</td>
#     </tr>
#   </tbody>
# </table>
# <br><strong>Training MLP 4, &ensp; h = [4, 2]</strong>
# <style type="text/css">
# #T_0f9f5_row3_col0, #T_0f9f5_row3_col1, #T_0f9f5_row3_col2, #T_0f9f5_row3_col3, #T_0f9f5_row3_col4, #T_0f9f5_row3_col5, #T_0f9f5_row3_col6 {
#   background-color: #F4DCF3;
# }
# </style>
# <table id="T_0f9f5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0f9f5_level0_col0" class="col_heading level0 col0" >dropout_rate</th>
#       <th id="T_0f9f5_level0_col1" class="col_heading level0 col1" >lr</th>
#       <th id="T_0f9f5_level0_col2" class="col_heading level0 col2" >train_roc_auc_mean</th>
#       <th id="T_0f9f5_level0_col3" class="col_heading level0 col3" >val_roc_auc_mean</th>
#       <th id="T_0f9f5_level0_col4" class="col_heading level0 col4" >train_f1_mean</th>
#       <th id="T_0f9f5_level0_col5" class="col_heading level0 col5" >val_f1_mean</th>
#       <th id="T_0f9f5_level0_col6" class="col_heading level0 col6" >label</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0f9f5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0f9f5_row0_col0" class="data row0 col0" >0.200000</td>
#       <td id="T_0f9f5_row0_col1" class="data row0 col1" >0.001000</td>
#       <td id="T_0f9f5_row0_col2" class="data row0 col2" >0.680104</td>
#       <td id="T_0f9f5_row0_col3" class="data row0 col3" >0.592213</td>
#       <td id="T_0f9f5_row0_col4" class="data row0 col4" >0.682397</td>
#       <td id="T_0f9f5_row0_col5" class="data row0 col5" >0.669426</td>
#       <td id="T_0f9f5_row0_col6" class="data row0 col6" >drop=0.2, lr=0.001</td>
#     </tr>
#     <tr>
#       <th id="T_0f9f5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_0f9f5_row1_col0" class="data row1 col0" >0.200000</td>
#       <td id="T_0f9f5_row1_col1" class="data row1 col1" >0.000500</td>
#       <td id="T_0f9f5_row1_col2" class="data row1 col2" >0.645517</td>
#       <td id="T_0f9f5_row1_col3" class="data row1 col3" >0.567158</td>
#       <td id="T_0f9f5_row1_col4" class="data row1 col4" >0.738201</td>
#       <td id="T_0f9f5_row1_col5" class="data row1 col5" >0.718473</td>
#       <td id="T_0f9f5_row1_col6" class="data row1 col6" >drop=0.2, lr=0.0005</td>
#     </tr>
#     <tr>
#       <th id="T_0f9f5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_0f9f5_row2_col0" class="data row2 col0" >0.300000</td>
#       <td id="T_0f9f5_row2_col1" class="data row2 col1" >0.001000</td>
#       <td id="T_0f9f5_row2_col2" class="data row2 col2" >0.687082</td>
#       <td id="T_0f9f5_row2_col3" class="data row2 col3" >0.588438</td>
#       <td id="T_0f9f5_row2_col4" class="data row2 col4" >0.705098</td>
#       <td id="T_0f9f5_row2_col5" class="data row2 col5" >0.686501</td>
#       <td id="T_0f9f5_row2_col6" class="data row2 col6" >drop=0.3, lr=0.001</td>
#     </tr>
#     <tr>
#       <th id="T_0f9f5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_0f9f5_row3_col0" class="data row3 col0" >0.300000</td>
#       <td id="T_0f9f5_row3_col1" class="data row3 col1" >0.000500</td>
#       <td id="T_0f9f5_row3_col2" class="data row3 col2" >0.662054</td>
#       <td id="T_0f9f5_row3_col3" class="data row3 col3" >0.595026</td>
#       <td id="T_0f9f5_row3_col4" class="data row3 col4" >0.700073</td>
#       <td id="T_0f9f5_row3_col5" class="data row3 col5" >0.684095</td>
#       <td id="T_0f9f5_row3_col6" class="data row3 col6" >drop=0.3, lr=0.0005</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Our best performing model was MLP 3 with the hyperparameters set to
#
# * Dropout rate: &emsp;
#   ${\color{Gray}{0.3}}$
# * Learning rate: &emsp;
#   ${\color{HotPink}{\eta}}
#       = {\color{HotPink}{0.0005}}$
# * Learning rate: &emsp;
#   ${\color{HotPink}{\eta}}
#       = {\color{HotPink}{0.0005}}$
# * Hidden states: &ensp;&nbsp;
#   ${\color{CornflowerBlue}{h}}_{3}
#       = [ {\color{CornflowerBlue}{16}}, \, {\color{CornflowerBlue}{8}} ]$
#
# Below, we run this model on our test set and generate a .csv file with our submission values.

# %%
# =========================
# Run Best Model MLP 3 on train set + valid set
# =========================
best_dropout = 0.3
best_lr = 0.0005

display(HTML(f"<strong>Training BEST model &emsp; MLP 6, &ensp; h = [16, 8]"
             f"&ensp; with dropout=0.3, lr=0.0005</strong>"))

best_model = build_mlp_3(
    input_shape=X_train_enc.shape[1],
    dropout=best_dropout
)

best_model.compile(
    optimizer=Adam(learning_rate=best_lr),
    loss="binary_crossentropy",
    metrics=[tf.keras.metrics.AUC(name="auc"),
             Precision(name="prec"),
             Recall(name="rec")]
)

early_stop = EarlyStopping(
    monitor="val_auc",
    patience=10,
    mode="max",
    restore_best_weights=True
)

history = best_model.fit(
    X_train_enc, y_train,
    validation_split=0.2,
    epochs=80,
    batch_size=64,
    verbose=1,
    class_weight=class_weights_dict,
    callbacks=[early_stop]
)


# =========================
# Run Best Model MLP 3 on test set
# =========================

test_probs = best_model.predict(X_test_enc, verbose=0).flatten()

submission_df = pd.DataFrame({
    "patient_id": test_raw["patient_id"],
    "target": test_probs
})

# -------------------------
# Generate submission
# -------------------------
display(HTML(f"<strong>Test MLP 3, &ensp; h = [16, 8]"
             f"&ensp; with dropout=0.3, lr=0.0005</strong>"))
display(submission_df.head())
submission_path = "submission.csv"
submission_df.to_csv(submission_path, index=False)
# Out:
# <strong>Training BEST model &emsp; MLP 6, &ensp; h = [16, 8]&ensp; with dropout=0.3, lr=0.0005</strong>
# Epoch 1/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 3s 12ms/step - auc: 0.4648 - loss: 0.9233 - prec: 0.9075 - rec: 0.3782 - val_auc: 0.4451 - val_loss: 0.7524 - val_prec: 0.8817 - val_rec: 0.3423
# Epoch 2/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.4634 - loss: 0.8754 - prec: 0.9096 - rec: 0.4023 - val_auc: 0.4610 - val_loss: 0.7843 - val_prec: 0.8750 - val_rec: 0.3004
# Epoch 3/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.4893 - loss: 0.8518 - prec: 0.9057 - rec: 0.4037 - val_auc: 0.4770 - val_loss: 0.7781 - val_prec: 0.8789 - val_rec: 0.3333
# Epoch 4/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5099 - loss: 0.8243 - prec: 0.9080 - rec: 0.4384 - val_auc: 0.4867 - val_loss: 0.7642 - val_prec: 0.8862 - val_rec: 0.3653
# Epoch 5/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - auc: 0.5040 - loss: 0.7621 - prec: 0.9201 - rec: 0.4386 - val_auc: 0.4940 - val_loss: 0.7400 - val_prec: 0.8925 - val_rec: 0.4062
# Epoch 6/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5175 - loss: 0.7424 - prec: 0.9180 - rec: 0.4589 - val_auc: 0.5025 - val_loss: 0.7320 - val_prec: 0.8968 - val_rec: 0.4162
# Epoch 7/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5124 - loss: 0.7592 - prec: 0.9230 - rec: 0.4736 - val_auc: 0.5127 - val_loss: 0.7171 - val_prec: 0.8952 - val_rec: 0.4431
# Epoch 8/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5184 - loss: 0.7375 - prec: 0.9149 - rec: 0.4695 - val_auc: 0.5159 - val_loss: 0.7133 - val_prec: 0.9006 - val_rec: 0.4521
# Epoch 9/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5132 - loss: 0.7272 - prec: 0.9132 - rec: 0.4746 - val_auc: 0.5183 - val_loss: 0.7055 - val_prec: 0.9033 - val_rec: 0.4661
# Epoch 10/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5381 - loss: 0.6963 - prec: 0.9280 - rec: 0.4882 - val_auc: 0.5212 - val_loss: 0.7027 - val_prec: 0.9006 - val_rec: 0.4701
# Epoch 11/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5680 - loss: 0.6968 - prec: 0.9241 - rec: 0.4988 - val_auc: 0.5224 - val_loss: 0.6947 - val_prec: 0.9033 - val_rec: 0.4850
# Epoch 12/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5449 - loss: 0.6855 - prec: 0.9292 - rec: 0.5160 - val_auc: 0.5298 - val_loss: 0.6903 - val_prec: 0.9081 - val_rec: 0.5030
# Epoch 13/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5477 - loss: 0.6777 - prec: 0.9250 - rec: 0.5169 - val_auc: 0.5316 - val_loss: 0.6869 - val_prec: 0.9079 - val_rec: 0.5020
# Epoch 14/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5451 - loss: 0.7277 - prec: 0.9151 - rec: 0.5247 - val_auc: 0.5362 - val_loss: 0.6857 - val_prec: 0.9069 - val_rec: 0.4960
# Epoch 15/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5244 - loss: 0.7520 - prec: 0.9106 - rec: 0.5385 - val_auc: 0.5399 - val_loss: 0.6800 - val_prec: 0.9065 - val_rec: 0.5130
# Epoch 16/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5551 - loss: 0.7198 - prec: 0.9246 - rec: 0.5450 - val_auc: 0.5437 - val_loss: 0.6796 - val_prec: 0.9070 - val_rec: 0.5160
# Epoch 17/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5486 - loss: 0.7274 - prec: 0.9101 - rec: 0.5367 - val_auc: 0.5446 - val_loss: 0.6806 - val_prec: 0.9078 - val_rec: 0.5110
# Epoch 18/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5669 - loss: 0.7098 - prec: 0.9197 - rec: 0.5486 - val_auc: 0.5451 - val_loss: 0.6817 - val_prec: 0.9085 - val_rec: 0.5150
# Epoch 19/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5630 - loss: 0.7046 - prec: 0.9225 - rec: 0.5579 - val_auc: 0.5470 - val_loss: 0.6748 - val_prec: 0.9077 - val_rec: 0.5399
# Epoch 20/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5994 - loss: 0.6603 - prec: 0.9381 - rec: 0.5681 - val_auc: 0.5485 - val_loss: 0.6750 - val_prec: 0.9045 - val_rec: 0.5389
# Epoch 21/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5839 - loss: 0.6813 - prec: 0.9347 - rec: 0.5853 - val_auc: 0.5513 - val_loss: 0.6774 - val_prec: 0.9061 - val_rec: 0.5200
# Epoch 22/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5816 - loss: 0.6694 - prec: 0.9314 - rec: 0.5824 - val_auc: 0.5536 - val_loss: 0.6755 - val_prec: 0.9044 - val_rec: 0.5379
# Epoch 23/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5730 - loss: 0.6864 - prec: 0.9299 - rec: 0.5702 - val_auc: 0.5573 - val_loss: 0.6755 - val_prec: 0.9069 - val_rec: 0.5349
# Epoch 24/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5928 - loss: 0.6741 - prec: 0.9338 - rec: 0.5759 - val_auc: 0.5567 - val_loss: 0.6720 - val_prec: 0.9030 - val_rec: 0.5479
# Epoch 25/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5863 - loss: 0.6510 - prec: 0.9326 - rec: 0.5847 - val_auc: 0.5620 - val_loss: 0.6721 - val_prec: 0.9043 - val_rec: 0.5469
# Epoch 26/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5725 - loss: 0.6719 - prec: 0.9304 - rec: 0.5781 - val_auc: 0.5666 - val_loss: 0.6712 - val_prec: 0.9092 - val_rec: 0.5599
# Epoch 27/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5786 - loss: 0.6665 - prec: 0.9338 - rec: 0.5660 - val_auc: 0.5682 - val_loss: 0.6743 - val_prec: 0.9079 - val_rec: 0.5409
# Epoch 28/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6102 - loss: 0.6502 - prec: 0.9348 - rec: 0.5801 - val_auc: 0.5697 - val_loss: 0.6711 - val_prec: 0.9107 - val_rec: 0.5599
# Epoch 29/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.5736 - loss: 0.6983 - prec: 0.9238 - rec: 0.5832 - val_auc: 0.5744 - val_loss: 0.6722 - val_prec: 0.9110 - val_rec: 0.5519
# Epoch 30/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6255 - loss: 0.6553 - prec: 0.9410 - rec: 0.5921 - val_auc: 0.5804 - val_loss: 0.6669 - val_prec: 0.9126 - val_rec: 0.5729
# Epoch 31/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6092 - loss: 0.6795 - prec: 0.9308 - rec: 0.5979 - val_auc: 0.5825 - val_loss: 0.6670 - val_prec: 0.9111 - val_rec: 0.5729
# Epoch 32/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6020 - loss: 0.6532 - prec: 0.9361 - rec: 0.5961 - val_auc: 0.5856 - val_loss: 0.6660 - val_prec: 0.9114 - val_rec: 0.5848
# Epoch 33/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6239 - loss: 0.6511 - prec: 0.9355 - rec: 0.5979 - val_auc: 0.5861 - val_loss: 0.6631 - val_prec: 0.9110 - val_rec: 0.5928
# Epoch 34/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6096 - loss: 0.6712 - prec: 0.9303 - rec: 0.6127 - val_auc: 0.5888 - val_loss: 0.6643 - val_prec: 0.9138 - val_rec: 0.6028
# Epoch 35/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6216 - loss: 0.6673 - prec: 0.9316 - rec: 0.5996 - val_auc: 0.5922 - val_loss: 0.6674 - val_prec: 0.9106 - val_rec: 0.5998
# Epoch 36/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6307 - loss: 0.6705 - prec: 0.9310 - rec: 0.6210 - val_auc: 0.5968 - val_loss: 0.6677 - val_prec: 0.9130 - val_rec: 0.5868
# Epoch 37/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6110 - loss: 0.6611 - prec: 0.9323 - rec: 0.6125 - val_auc: 0.6000 - val_loss: 0.6657 - val_prec: 0.9162 - val_rec: 0.5998
# Epoch 38/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6090 - loss: 0.6606 - prec: 0.9330 - rec: 0.6116 - val_auc: 0.6009 - val_loss: 0.6640 - val_prec: 0.9174 - val_rec: 0.6098
# Epoch 39/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6344 - loss: 0.6758 - prec: 0.9361 - rec: 0.6348 - val_auc: 0.6026 - val_loss: 0.6603 - val_prec: 0.9154 - val_rec: 0.6158
# Epoch 40/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6290 - loss: 0.6343 - prec: 0.9416 - rec: 0.6215 - val_auc: 0.6066 - val_loss: 0.6601 - val_prec: 0.9162 - val_rec: 0.6218
# Epoch 41/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6388 - loss: 0.6392 - prec: 0.9404 - rec: 0.6131 - val_auc: 0.6056 - val_loss: 0.6612 - val_prec: 0.9172 - val_rec: 0.6188
# Epoch 42/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6388 - loss: 0.6681 - prec: 0.9371 - rec: 0.6296 - val_auc: 0.6025 - val_loss: 0.6620 - val_prec: 0.9165 - val_rec: 0.6138
# Epoch 43/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6357 - loss: 0.6587 - prec: 0.9352 - rec: 0.6109 - val_auc: 0.6044 - val_loss: 0.6591 - val_prec: 0.9157 - val_rec: 0.6178
# Epoch 44/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6310 - loss: 0.6672 - prec: 0.9350 - rec: 0.6136 - val_auc: 0.6006 - val_loss: 0.6572 - val_prec: 0.9128 - val_rec: 0.6267
# Epoch 45/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6597 - loss: 0.6502 - prec: 0.9414 - rec: 0.6088 - val_auc: 0.6009 - val_loss: 0.6576 - val_prec: 0.9116 - val_rec: 0.6178
# Epoch 46/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6470 - loss: 0.6449 - prec: 0.9394 - rec: 0.6179 - val_auc: 0.6033 - val_loss: 0.6566 - val_prec: 0.9126 - val_rec: 0.6148
# Epoch 47/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6621 - loss: 0.6439 - prec: 0.9445 - rec: 0.6146 - val_auc: 0.6070 - val_loss: 0.6546 - val_prec: 0.9122 - val_rec: 0.6218
# Epoch 48/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6199 - loss: 0.6436 - prec: 0.9360 - rec: 0.6220 - val_auc: 0.6095 - val_loss: 0.6578 - val_prec: 0.9142 - val_rec: 0.6058
# Epoch 49/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6597 - loss: 0.6453 - prec: 0.9408 - rec: 0.6148 - val_auc: 0.6085 - val_loss: 0.6589 - val_prec: 0.9139 - val_rec: 0.6038
# Epoch 50/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6449 - loss: 0.6650 - prec: 0.9390 - rec: 0.6191 - val_auc: 0.6078 - val_loss: 0.6617 - val_prec: 0.9159 - val_rec: 0.5978
# Epoch 51/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6401 - loss: 0.6494 - prec: 0.9380 - rec: 0.6213 - val_auc: 0.6059 - val_loss: 0.6570 - val_prec: 0.9132 - val_rec: 0.6088
# Epoch 52/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6503 - loss: 0.6444 - prec: 0.9445 - rec: 0.6175 - val_auc: 0.6074 - val_loss: 0.6538 - val_prec: 0.9155 - val_rec: 0.6058
# Epoch 53/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6404 - loss: 0.6258 - prec: 0.9399 - rec: 0.6075 - val_auc: 0.6109 - val_loss: 0.6536 - val_prec: 0.9154 - val_rec: 0.6048
# Epoch 54/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6523 - loss: 0.6219 - prec: 0.9490 - rec: 0.6058 - val_auc: 0.6120 - val_loss: 0.6539 - val_prec: 0.9184 - val_rec: 0.6068
# Epoch 55/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6789 - loss: 0.6332 - prec: 0.9482 - rec: 0.6167 - val_auc: 0.6103 - val_loss: 0.6540 - val_prec: 0.9164 - val_rec: 0.6018
# Epoch 56/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6437 - loss: 0.6616 - prec: 0.9357 - rec: 0.6020 - val_auc: 0.6107 - val_loss: 0.6574 - val_prec: 0.9153 - val_rec: 0.5928
# Epoch 57/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6456 - loss: 0.6589 - prec: 0.9428 - rec: 0.6233 - val_auc: 0.6119 - val_loss: 0.6559 - val_prec: 0.9163 - val_rec: 0.6008
# Epoch 58/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6870 - loss: 0.6434 - prec: 0.9484 - rec: 0.6108 - val_auc: 0.6125 - val_loss: 0.6565 - val_prec: 0.9209 - val_rec: 0.5928
# Epoch 59/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6618 - loss: 0.6311 - prec: 0.9418 - rec: 0.6215 - val_auc: 0.6162 - val_loss: 0.6544 - val_prec: 0.9214 - val_rec: 0.5968
# Epoch 60/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6570 - loss: 0.6328 - prec: 0.9449 - rec: 0.6126 - val_auc: 0.6172 - val_loss: 0.6577 - val_prec: 0.9193 - val_rec: 0.5798
# Epoch 61/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6582 - loss: 0.6435 - prec: 0.9477 - rec: 0.6160 - val_auc: 0.6157 - val_loss: 0.6502 - val_prec: 0.9186 - val_rec: 0.5968
# Epoch 62/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6655 - loss: 0.6472 - prec: 0.9408 - rec: 0.6020 - val_auc: 0.6150 - val_loss: 0.6524 - val_prec: 0.9176 - val_rec: 0.5888
# Epoch 63/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6638 - loss: 0.6148 - prec: 0.9497 - rec: 0.6254 - val_auc: 0.6146 - val_loss: 0.6489 - val_prec: 0.9179 - val_rec: 0.6028
# Epoch 64/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6577 - loss: 0.6316 - prec: 0.9424 - rec: 0.6214 - val_auc: 0.6143 - val_loss: 0.6470 - val_prec: 0.9178 - val_rec: 0.6018
# Epoch 65/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6669 - loss: 0.6284 - prec: 0.9445 - rec: 0.6210 - val_auc: 0.6126 - val_loss: 0.6500 - val_prec: 0.9198 - val_rec: 0.5948
# Epoch 66/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6579 - loss: 0.6461 - prec: 0.9466 - rec: 0.6222 - val_auc: 0.6118 - val_loss: 0.6526 - val_prec: 0.9168 - val_rec: 0.5938
# Epoch 67/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6957 - loss: 0.6259 - prec: 0.9544 - rec: 0.6219 - val_auc: 0.6104 - val_loss: 0.6531 - val_prec: 0.9159 - val_rec: 0.5868
# Epoch 68/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6700 - loss: 0.6428 - prec: 0.9448 - rec: 0.6264 - val_auc: 0.6120 - val_loss: 0.6431 - val_prec: 0.9173 - val_rec: 0.6088
# Epoch 69/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6876 - loss: 0.6390 - prec: 0.9439 - rec: 0.6151 - val_auc: 0.6129 - val_loss: 0.6426 - val_prec: 0.9197 - val_rec: 0.6058
# Epoch 70/80
# 70/70 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - auc: 0.6605 - loss: 0.6558 - prec: 0.9425 - rec: 0.6151 - val_auc: 0.6151 - val_loss: 0.6438 - val_prec: 0.9195 - val_rec: 0.6038
# <strong>Test MLP 3, &ensp; h = [16, 8]&ensp; with dropout=0.3, lr=0.0005</strong>
#    patient_id    target
# 0        5526  0.686305
# 1         772  0.542313
# 2        7840  0.505504
# 3        2396  0.630720
# 4        1479  0.521915

# %%
# =========================
# Final Plot
# =========================
plt.plot(history.history["auc"], label="Train AUC")
plt.plot(history.history["val_auc"], label="Val AUC")
plt.title("Best MLP 3 — Training Curve")
plt.xlabel("Epoch")
plt.ylabel("AUC")
plt.legend()
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()

# %% [markdown]
# ---
# ## Discussion
#
# After running several MLP models, we learned that having too many hidden states within our dense layers puts the model at risk of overfitting, especially when when our dataset is relatively small. In our case, our validation set was only
# ${\color{ForestGreen}{n}}
#     = {\color{ForestGreen}{1400}}$,
# while our train set was much larger at
# ${\color{ForestGreen}{n}}
#     = {\color{ForestGreen}{5600}}$.
# This explains why having hundreds of hidden states at the dense layers during early model versions caused severe overfitting on the train set, like we saw with our iterations of MLP 1. There, we had a train set ROC-AUC score of
# $1.0$
# and a validation set ROC-AUC score of only
# $0.53$.
#
# Reducing the number of hidden states to
# ${\color{CornflowerBlue}{h}}_{3}
#     = [ {\color{CornflowerBlue}{16}}, \, {\color{CornflowerBlue}{8}} ]$
# improved these overfitting issues. When we applied this to the third version of our model, MLP 3, our maximum validation set ROC-AUC score hovered around
# $0.59$,
# with a corresponding train set ROC-AUC score of
# $0.78$.
#
# For that particular model, we found the best results at a dropout rate of
# ${\color{Gray}{0.3}}$
# and a learning rate of
# ${\color{HotPink}{\eta}}
#     = {\color{HotPink}{0.0005}}$.
# This shows that increasing the dropout rate to avoid overfitting helps improve model performance, while decreasing the learning rate allows it to reach convergence faster.
#
# To make future improvements to this model, I would go wider rather than deeper. I would keep the number of hidden states at each dense layer to
# ${\color{CornflowerBlue}{h}}
#     = [ {\color{CornflowerBlue}{16}}, \, {\color{CornflowerBlue}{8}} ]$,
# but I would have multiple dense layers and input a different slice of our input at each one. The manual slicing I did by group + encoding during the EDA phase of this project would be a good starting point.

# %% [markdown]
# ---
# # 6. Resources
#
# * Barbosa, F. T. (2025). Dental Implant 10-Year Survival Prediction. https://kaggle.com/competitions/dental-implant-10-year-survival-prediction
